# %%
"""
Project Title: Job Matching and Visualization

Problem Statement:
As part of this project, we aim to develop a system that efficiently matches job listings with resumes based on skills, experience, and education. 

Solution Overview:
To address this problem, we will implement a multi-step approach:
1. Data Preparation: We'll gather job listings and resumes data and preprocess it for indexing.
2. Indexing: We'll index the preprocessed data into Elasticsearch, a highly scalable search engine.
3. Matching Algorithm: We'll develop an algorithm to match resumes with job listings based on key criteria such as skills, experience, and education.


Approach:
- Utilize Python and Elasticsearch for data preprocessing, indexing, and matching.
- Implement NLP techniques for feature extraction and keyword matching.
- Test and iterate on the matching algorithm to improve accuracy and efficiency.
- Document each step and provide clear explanations for transparency and reproducibility.
"""
# Out:
# "\nProject Title: Job Matching and Visualization\n\nProblem Statement:\nAs part of this project, we aim to develop a system that efficiently matches job listings with resumes based on skills, experience, and education. \n\nSolution Overview:\nTo address this problem, we will implement a multi-step approach:\n1. Data Preparation: We'll gather job listings and resumes data and preprocess it for indexing.\n2. Indexing: We'll index the preprocessed data into Elasticsearch, a highly scalable search engine.\n3. Matching Algorithm: We'll develop an algorithm to match resumes with job listings based on key criteria such as skills, experience, and education.\n\n\nApproach:\n- Utilize Python and Elasticsearch for data preprocessing, indexing, and matching.\n- Implement NLP techniques for feature extraction and keyword matching.\n- Test and iterate on the matching algorithm to improve accuracy and efficiency.\n- Document each step and provide clear explanations for transparency and reproducibility.\n"

# %%
pip install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (8.12.0)
# Requirement already satisfied: elastic-transport<9,>=8 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from elasticsearch) (8.12.0)
# Requirement already satisfied: urllib3<3,>=1.26.2 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from elastic-transport<9,>=8->elasticsearch) (2.0.7)
# Requirement already satisfied: certifi in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from elastic-transport<9,>=8->elasticsearch) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
"""
Generate Fake Job Data using Faker

This section generates synthetic job data using the Faker library while considering specific aspects required for the job data. Faker is a Python library that generates fake data such as names, addresses, and job titles, which is useful for creating realistic but synthetic datasets for testing and development purposes.

In this script, we'll use Faker to generate job-related data for various fields such as required_skills, experience_title, and required_education. We'll ensure that the generated job data aligns with certain aspects, such as the required skills, experience titles, and required education levels specified by the user.

By using Faker, we can easily create large volumes of diverse job data that closely resemble real-world job listings. This synthetic data will be useful for testing the matching algorithm and visualizing the job data in Kibana.

"""
# Out:
# "\nGenerate Fake Job Data using Faker\n\nThis section generates synthetic job data using the Faker library while considering specific aspects required for the job data. Faker is a Python library that generates fake data such as names, addresses, and job titles, which is useful for creating realistic but synthetic datasets for testing and development purposes.\n\nIn this script, we'll use Faker to generate job-related data for various fields such as required_skills, experience_title, and required_education. We'll ensure that the generated job data aligns with certain aspects, such as the required skills, experience titles, and required education levels specified by the user.\n\nBy using Faker, we can easily create large volumes of diverse job data that closely resemble real-world job listings. This synthetic data will be useful for testing the matching algorithm and visualizing the job data in Kibana.\n\n"

# %%
from faker import Faker
import random

fake = Faker()

# Provided sample skills and degrees
sample_skills = {
    "Computer Science": ["Python", "Java", "C++", "Machine Learning", "Data Analysis"],
    "Mechanical Engineering": ["CAD", "SolidWorks", "Thermodynamics", "Structural Analysis"],
    "Electrical Engineering": ["Circuit Design", "Microcontrollers", "Power Systems"],
    "Chemical Engineering": ["Chemical Process Design", "Chemical Kinetics", "Mass Transfer"],
    "Biomedical Engineering": ["Biomaterials", "Medical Imaging", "Biomechanics"],
}

sample_degrees = [
    "Bachelor of Science in Computer Science",
    "Bachelor of Engineering in Mechanical Engineering",
    "Bachelor of Science in Electrical Engineering",
    "Bachelor of Science in Chemical Engineering",
    "Bachelor of Science in Biomedical Engineering",
]

degree_to_field = {
    "Bachelor of Science in Computer Science": "Computer Science",
    "Bachelor of Engineering in Mechanical Engineering": "Mechanical Engineering",
    "Bachelor of Science in Electrical Engineering": "Electrical Engineering",
    "Bachelor of Science in Chemical Engineering": "Chemical Engineering",
    "Bachelor of Science in Biomedical Engineering": "Biomedical Engineering",
}

def generate_job_data(num_jobs=10):
    job_data = []
    for _ in range(num_jobs):
        degree = random.choice(sample_degrees)
        field = degree_to_field[degree]
        num_skills = len(sample_skills[field])
        num_skills_to_sample = min(random.randint(2, 4), num_skills)

        job = {
            "required_skills": random.sample(sample_skills[field], k=num_skills_to_sample),
            "experience_title": fake.job(),
            "required_education": degree
        }
        job_data.append(job)
    
    return job_data

# Generate job data
jobs_data = generate_job_data(1000)

# Display a few generated job data
for job in jobs_data[:10]:
    print(job)

import string

def generate_provider_name(index):
    # Generates provider names like 'Provider A', 'Provider B', ...
    return f"Provider {string.ascii_uppercase[index % 26]}"

# Add a 'provider' field to each job
for index, job in enumerate(jobs_data):
    job['provider'] = generate_provider_name(index)

# Example: Print the first 10 jobs to see the provider names
for job in jobs_data[:1000]:
    print(job)
# Out:
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Information systems manager', 'required_education': 'Bachelor of Science in Biomedical Engineering'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Prison officer', 'required_education': 'Bachelor of Science in Biomedical Engineering'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'TEFL teacher', 'required_education': 'Bachelor of Science in Chemical Engineering'}
# {'required_skills': ['Machine Learning', 'Python', 'C++'], 'experience_title': 'Building control surveyor', 'required_education': 'Bachelor of Science in Computer Science'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Occupational therapist', 'required_education': 'Bachelor of Science in Electrical Engineering'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'Land', 'required_education': 'Bachelor of Science in Biomedical Engineering'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Geoscientist', 'required_education': 'Bachelor of Science in Biomedical Engineering'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Teacher, music', 'required_education': 'Bachelor of Science in Biomedical Engineering'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Web designer', 'required_education': 'Bachelor of Science in Biomedical Engineering'}
# {'required_skills': ['Thermodynamics', 'SolidWorks', 'Structural Analysis', 'CAD'], 'experience_title': 'Mining engineer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Information systems manager', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Prison officer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'TEFL teacher', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Machine Learning', 'Python', 'C++'], 'experience_title': 'Building control surveyor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider D'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Occupational therapist', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'Land', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Geoscientist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Teacher, music', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Web designer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Thermodynamics', 'SolidWorks', 'Structural Analysis', 'CAD'], 'experience_title': 'Mining engineer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['C++', 'Java'], 'experience_title': 'Early years teacher', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider K'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Photographer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Lecturer, further education', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Technical author', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Circuit Design', 'Power Systems'], 'experience_title': 'Microbiologist', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Retail merchandiser', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Osteopath', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Java', 'C++', 'Machine Learning', 'Data Analysis'], 'experience_title': 'Financial manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider R'}
# {'required_skills': ['Circuit Design', 'Microcontrollers'], 'experience_title': 'Forensic scientist', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Thermodynamics', 'Structural Analysis', 'CAD', 'SolidWorks'], 'experience_title': 'General practice doctor', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['SolidWorks', 'Structural Analysis', 'CAD'], 'experience_title': 'Marine scientist', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Structural Analysis', 'CAD', 'SolidWorks', 'Thermodynamics'], 'experience_title': 'Development worker, international aid', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Actor', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Biomechanics', 'Biomaterials'], 'experience_title': 'Journalist, broadcasting', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'Best boy', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['C++', 'Machine Learning', 'Data Analysis'], 'experience_title': 'Education officer, community', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Z'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Programmer, systems', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Office manager', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Data Analysis', 'Java', 'Python'], 'experience_title': 'Field seismologist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider C'}
# {'required_skills': ['Python', 'C++', 'Machine Learning', 'Data Analysis'], 'experience_title': 'Electrical engineer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider D'}
# {'required_skills': ['Medical Imaging', 'Biomaterials'], 'experience_title': 'TEFL teacher', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Biomaterials', 'Biomechanics'], 'experience_title': 'Investment banker, operational', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Scientist, research (medical)', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Java', 'Python', 'Data Analysis', 'C++'], 'experience_title': 'Engineer, water', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider H'}
# {'required_skills': ['C++', 'Machine Learning', 'Data Analysis', 'Python'], 'experience_title': 'Waste management officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider I'}
# {'required_skills': ['Thermodynamics', 'CAD'], 'experience_title': 'Soil scientist', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'experience_title': 'Sports development officer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Administrator, education', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Estate manager/land agent', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'IT trainer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['C++', 'Data Analysis', 'Machine Learning', 'Java'], 'experience_title': 'Barista', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider O'}
# {'required_skills': ['Circuit Design', 'Microcontrollers'], 'experience_title': 'Clinical scientist, histocompatibility and immunogenetics', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['SolidWorks', 'CAD', 'Thermodynamics', 'Structural Analysis'], 'experience_title': 'Immunologist', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Therapist, sports', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Mudlogger', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Garment/textile technologist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Thermodynamics', 'Structural Analysis'], 'experience_title': 'Hydrographic surveyor', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['SolidWorks', 'Thermodynamics'], 'experience_title': 'Programmer, applications', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Microcontrollers', 'Circuit Design'], 'experience_title': 'Primary school teacher', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'experience_title': 'Public relations account executive', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Pharmacologist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['CAD', 'SolidWorks'], 'experience_title': 'Commercial art gallery manager', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'experience_title': 'Product manager', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Geologist, engineering', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Medical Imaging', 'Biomaterials'], 'experience_title': 'Jewellery designer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'experience_title': 'Interior and spatial designer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['C++', 'Machine Learning', 'Python'], 'experience_title': 'Research officer, trade union', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider E'}
# {'required_skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'experience_title': 'Press photographer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Furniture designer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Java', 'Data Analysis', 'Machine Learning'], 'experience_title': 'Site engineer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider H'}
# {'required_skills': ['Java', 'Machine Learning'], 'experience_title': 'Engineer, broadcasting (operations)', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider I'}
# {'required_skills': ['SolidWorks', 'Structural Analysis'], 'experience_title': 'Journalist, magazine', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Insurance claims handler', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Structural Analysis', 'Thermodynamics', 'CAD'], 'experience_title': 'Geneticist, molecular', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Power Systems', 'Microcontrollers'], 'experience_title': 'Sport and exercise psychologist', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Chief Marketing Officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['C++', 'Python'], 'experience_title': 'Solicitor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider O'}
# {'required_skills': ['C++', 'Java', 'Data Analysis', 'Machine Learning'], 'experience_title': 'Buyer, retail', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider P'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Horticultural consultant', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['CAD', 'Thermodynamics', 'SolidWorks', 'Structural Analysis'], 'experience_title': 'Further education lecturer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Structural engineer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Circuit Design', 'Microcontrollers', 'Power Systems'], 'experience_title': 'Administrator, education', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Runner, broadcasting/film/video', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Financial trader', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Geographical information systems officer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Java', 'Machine Learning', 'Python'], 'experience_title': 'Race relations officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider X'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Scientist, research (maths)', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Machine Learning', 'Java'], 'experience_title': 'IT consultant', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Z'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Private music teacher', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Licensed conveyancer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Python', 'C++', 'Java', 'Machine Learning'], 'experience_title': 'General practice doctor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider C'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Translator', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Power Systems', 'Microcontrollers'], 'experience_title': 'Camera operator', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Futures trader', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Mental health nurse', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Accountant, chartered', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Radiographer, diagnostic', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Public affairs consultant', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['CAD', 'Structural Analysis', 'SolidWorks'], 'experience_title': 'Armed forces logistics/support/administrative officer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Java', 'C++'], 'experience_title': 'Soil scientist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider L'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Social researcher', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Microcontrollers', 'Circuit Design'], 'experience_title': 'Analytical chemist', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Microcontrollers', 'Circuit Design'], 'experience_title': 'Quantity surveyor', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Python', 'Java', 'C++', 'Data Analysis'], 'experience_title': 'Hospital doctor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider P'}
# {'required_skills': ['Biomechanics', 'Medical Imaging'], 'experience_title': 'Psychologist, clinical', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Python', 'Java', 'C++', 'Machine Learning'], 'experience_title': 'Make', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider R'}
# {'required_skills': ['Medical Imaging', 'Biomaterials'], 'experience_title': 'Optician, dispensing', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Data Analysis', 'Machine Learning', 'Java', 'Python'], 'experience_title': 'Dispensing optician', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider T'}
# {'required_skills': ['Python', 'Java', 'Data Analysis', 'C++'], 'experience_title': 'Administrator, arts', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider U'}
# {'required_skills': ['Thermodynamics', 'Structural Analysis', 'SolidWorks'], 'experience_title': 'Camera operator', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Geologist, wellsite', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'experience_title': 'Academic librarian', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Oceanographer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Therapist, art', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Java', 'Machine Learning', 'Data Analysis', 'C++'], 'experience_title': 'Quarry manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider A'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'Pathologist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Public librarian', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Museum education officer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Python', 'C++', 'Java'], 'experience_title': 'Company secretary', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider E'}
# {'required_skills': ['CAD', 'Thermodynamics', 'SolidWorks'], 'experience_title': 'Armed forces training and education officer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Power Systems', 'Circuit Design'], 'experience_title': 'Magazine features editor', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Python', 'C++', 'Machine Learning', 'Java'], 'experience_title': 'Hotel manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider H'}
# {'required_skills': ['Biomechanics', 'Biomaterials'], 'experience_title': 'Automotive engineer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Biomechanics', 'Biomaterials'], 'experience_title': 'Programme researcher, broadcasting/film/video', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Ship broker', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Java', 'Python', 'Data Analysis'], 'experience_title': 'Chief Strategy Officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider L'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Phytotherapist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Fitness centre manager', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['CAD', 'SolidWorks', 'Thermodynamics'], 'experience_title': 'Armed forces technical officer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'experience_title': 'Travel agency manager', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Print production planner', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer'], 'experience_title': 'IT consultant', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['C++', 'Machine Learning', 'Java', 'Python'], 'experience_title': 'Medical illustrator', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider S'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Animal nutritionist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Data Analysis', 'Machine Learning', 'Java', 'C++'], 'experience_title': 'Secondary school teacher', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider U'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Solicitor', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Lecturer, higher education', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['C++', 'Data Analysis', 'Machine Learning', 'Python'], 'experience_title': 'Health visitor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider X'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Oceanographer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Toxicologist', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Circuit Design', 'Microcontrollers', 'Power Systems'], 'experience_title': 'Tax adviser', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Film/video editor', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Java', 'Machine Learning', 'Data Analysis', 'C++'], 'experience_title': 'Chief Executive Officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider C'}
# {'required_skills': ['Circuit Design', 'Microcontrollers'], 'experience_title': 'Medical laboratory scientific officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Microcontrollers', 'Circuit Design'], 'experience_title': 'Accountant, chartered management', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Arboriculturist', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Engineer, control and instrumentation', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Analytical chemist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'experience_title': 'Facilities manager', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': "Nurse, children's", 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Machine Learning', 'C++', 'Data Analysis'], 'experience_title': 'Commercial art gallery manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider K'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Local government officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Solicitor, Scotland', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Medical Imaging', 'Biomaterials'], 'experience_title': 'IT consultant', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['SolidWorks', 'CAD', 'Structural Analysis'], 'experience_title': 'Systems analyst', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Building surveyor', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Sound technician, broadcasting/film/video', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Microcontrollers', 'Circuit Design'], 'experience_title': 'Research scientist (medical)', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Radio broadcast assistant', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['C++', 'Machine Learning'], 'experience_title': 'Nurse, adult', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider T'}
# {'required_skills': ['Circuit Design', 'Microcontrollers', 'Power Systems'], 'experience_title': 'Solicitor', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['C++', 'Data Analysis', 'Python', 'Machine Learning'], 'experience_title': 'Land/geomatics surveyor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider V'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Statistician', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Thermodynamics', 'CAD', 'Structural Analysis'], 'experience_title': 'IT technical support officer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Lexicographer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Development worker, international aid', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Pharmacist, community', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Biomechanics', 'Biomaterials'], 'experience_title': 'Conservation officer, nature', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Sound technician, broadcasting/film/video', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Machine Learning', 'Data Analysis', 'Java', 'Python'], 'experience_title': 'Information officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider D'}
# {'required_skills': ['Biomechanics', 'Biomaterials'], 'experience_title': 'Dentist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Data Analysis', 'Java', 'C++'], 'experience_title': 'Aid worker', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider F'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Environmental manager', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Structural Analysis', 'Thermodynamics', 'CAD', 'SolidWorks'], 'experience_title': 'Civil Service fast streamer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Equities trader', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Python', 'Machine Learning', 'Data Analysis', 'C++'], 'experience_title': 'Licensed conveyancer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider J'}
# {'required_skills': ['Machine Learning', 'C++', 'Java'], 'experience_title': 'Advertising copywriter', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider K'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'General practice doctor', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Psychotherapist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Microcontrollers', 'Circuit Design'], 'experience_title': 'Teacher, primary school', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Machine Learning', 'C++', 'Python', 'Data Analysis'], 'experience_title': 'Dietitian', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider O'}
# {'required_skills': ['Circuit Design', 'Microcontrollers'], 'experience_title': 'Firefighter', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['CAD', 'SolidWorks', 'Thermodynamics', 'Structural Analysis'], 'experience_title': 'Restaurant manager, fast food', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Biomaterials', 'Biomechanics'], 'experience_title': 'Fitness centre manager', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Transport planner', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Amenity horticulturist', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['CAD', 'Structural Analysis', 'Thermodynamics'], 'experience_title': 'Air cabin crew', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Machine Learning', 'C++'], 'experience_title': 'Film/video editor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider V'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Statistician', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Biomechanics', 'Medical Imaging'], 'experience_title': 'Water engineer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Python', 'Java', 'Data Analysis', 'Machine Learning'], 'experience_title': 'Professor Emeritus', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Y'}
# {'required_skills': ['Data Analysis', 'C++'], 'experience_title': 'Hydrologist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Z'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'Legal executive', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Conservator, furniture', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Psychologist, clinical', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Academic librarian', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Surveyor, commercial/residential', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Structural Analysis', 'SolidWorks', 'CAD'], 'experience_title': 'Surveyor, commercial/residential', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Scientist, research (maths)', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Data Analysis', 'Python'], 'experience_title': 'Building surveyor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider H'}
# {'required_skills': ['Biomaterials', 'Medical Imaging'], 'experience_title': 'Television/film/video producer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Journalist, broadcasting', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Journalist, newspaper', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Java', 'Machine Learning', 'Python'], 'experience_title': 'Materials engineer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider L'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Race relations officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Python', 'Machine Learning', 'Java', 'C++'], 'experience_title': 'Merchandiser, retail', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider N'}
# {'required_skills': ['SolidWorks', 'Structural Analysis', 'Thermodynamics', 'CAD'], 'experience_title': 'Games developer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Production manager', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Thermodynamics', 'SolidWorks', 'Structural Analysis'], 'experience_title': 'Comptroller', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Engineer, water', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Trade mark attorney', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'experience_title': 'Photographer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'experience_title': 'Geographical information systems officer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Machine Learning', 'Java', 'C++', 'Data Analysis'], 'experience_title': 'Office manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider V'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Chiropractor', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Python', 'C++', 'Machine Learning'], 'experience_title': 'Teacher, music', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider X'}
# {'required_skills': ['Python', 'Machine Learning', 'Java'], 'experience_title': 'Investment banker, operational', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Y'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Merchandiser, retail', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'experience_title': 'Graphic designer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Museum education officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Educational psychologist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['C++', 'Python', 'Java', 'Data Analysis'], 'experience_title': 'Chief Marketing Officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider D'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Homeopath', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Clinical scientist, histocompatibility and immunogenetics', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Power Systems', 'Microcontrollers'], 'experience_title': 'Writer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Nurse, learning disability', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Public affairs consultant', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Sales professional, IT', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Medical laboratory scientific officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider K'}
# ...
# {'required_skills': ['C++', 'Python', 'Java'], 'experience_title': 'Sub', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider P'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Visual merchandiser', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Structural Analysis', 'Thermodynamics', 'SolidWorks', 'CAD'], 'experience_title': 'Insurance account manager', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Machine Learning', 'C++', 'Python', 'Java'], 'experience_title': 'Regulatory affairs officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider S'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Arboriculturist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['CAD', 'Structural Analysis', 'SolidWorks', 'Thermodynamics'], 'experience_title': 'Camera operator', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Acupuncturist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'Doctor, hospital', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Power Systems', 'Microcontrollers'], 'experience_title': 'Technical brewer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['C++', 'Java', 'Python', 'Data Analysis'], 'experience_title': 'Air traffic controller', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Y'}
# {'required_skills': ['CAD', 'SolidWorks', 'Thermodynamics'], 'experience_title': 'Seismic interpreter', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Circuit Design', 'Microcontrollers'], 'experience_title': 'Conservator, museum/gallery', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['CAD', 'Thermodynamics', 'Structural Analysis', 'SolidWorks'], 'experience_title': 'Surveyor, insurance', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Teacher, music', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Data Analysis', 'C++'], 'experience_title': 'Programmer, multimedia', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider D'}
# {'required_skills': ['Structural Analysis', 'Thermodynamics'], 'experience_title': 'Chartered legal executive (England and Wales)', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['CAD', 'Structural Analysis'], 'experience_title': 'Sales professional, IT', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Location manager', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Java', 'Python', 'Machine Learning'], 'experience_title': 'Building surveyor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider H'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Investment analyst', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Audiological scientist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Circuit Design', 'Power Systems'], 'experience_title': 'Doctor, hospital', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'experience_title': 'Journalist, magazine', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Machine Learning', 'Python', 'Java', 'Data Analysis'], 'experience_title': 'Biochemist, clinical', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider M'}
# {'required_skills': ['Thermodynamics', 'Structural Analysis', 'CAD'], 'experience_title': 'Transport planner', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Environmental education officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Police officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Java', 'Data Analysis', 'C++'], 'experience_title': 'Film/video editor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Q'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Contracting civil engineer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Thermodynamics', 'Structural Analysis', 'SolidWorks', 'CAD'], 'experience_title': 'Counsellor', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Field trials officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Scientist, research (life sciences)', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Biomechanics', 'Medical Imaging'], 'experience_title': 'Educational psychologist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Producer, television/film/video', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['CAD', 'Thermodynamics', 'SolidWorks', 'Structural Analysis'], 'experience_title': 'Agricultural engineer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Furniture designer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'experience_title': 'Fashion designer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Machine Learning', 'Java', 'Python', 'C++'], 'experience_title': 'Tree surgeon', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider A'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Patent attorney', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Contractor', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'experience_title': 'Osteopath', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Designer, textile', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Education officer, community', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Python', 'C++'], 'experience_title': 'Fine artist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider G'}
# {'required_skills': ['Biomechanics', 'Medical Imaging'], 'experience_title': 'Arts development officer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Horticulturist, amenity', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['CAD', 'SolidWorks', 'Structural Analysis'], 'experience_title': 'Secretary, company', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Occupational therapist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'experience_title': 'Fisheries officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Java', 'Python'], 'experience_title': 'Chartered public finance accountant', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider M'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Colour technologist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Circuit Design', 'Microcontrollers', 'Power Systems'], 'experience_title': 'Clinical research associate', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['SolidWorks', 'Structural Analysis', 'Thermodynamics', 'CAD'], 'experience_title': 'Company secretary', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Java', 'Data Analysis', 'C++', 'Machine Learning'], 'experience_title': 'Clinical research associate', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Q'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'TEFL teacher', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Water quality scientist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Minerals surveyor', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'Haematologist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Medical Imaging', 'Biomaterials'], 'experience_title': 'Surveyor, quantity', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['SolidWorks', 'Structural Analysis', 'CAD'], 'experience_title': 'English as a second language teacher', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Risk analyst', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Structural Analysis', 'CAD', 'Thermodynamics'], 'experience_title': 'Colour technologist', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Automotive engineer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['SolidWorks', 'CAD', 'Structural Analysis', 'Thermodynamics'], 'experience_title': 'Emergency planning/management officer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Data Analysis', 'Python', 'C++'], 'experience_title': 'Psychologist, educational', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider B'}
# {'required_skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'experience_title': 'Psychologist, prison and probation services', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Data Analysis', 'Java'], 'experience_title': 'Programme researcher, broadcasting/film/video', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider D'}
# {'required_skills': ['C++', 'Python'], 'experience_title': 'Engineer, civil (contracting)', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider E'}
# {'required_skills': ['Machine Learning', 'Data Analysis'], 'experience_title': 'Brewing technologist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider F'}
# {'required_skills': ['C++', 'Python', 'Machine Learning'], 'experience_title': 'Medical sales representative', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider G'}
# {'required_skills': ['Python', 'Machine Learning', 'Java'], 'experience_title': 'Glass blower/designer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider H'}
# {'required_skills': ['CAD', 'SolidWorks', 'Thermodynamics', 'Structural Analysis'], 'experience_title': 'Air broker', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Structural Analysis', 'CAD', 'Thermodynamics'], 'experience_title': 'Barista', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'experience_title': 'Accountant, chartered', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Runner, broadcasting/film/video', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider L'}

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
pip install faker
# Out:
# Requirement already satisfied: faker in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (22.7.0)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\acer\appdata\roaming\python\python311\site-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from faker import Faker
import random

fake = Faker()






# Sample data
sample_degrees = [
    "Bachelor of Science in Computer Science",
    "Bachelor of Engineering in Mechanical Engineering",
    "Bachelor of Science in Electrical Engineering",
    "Bachelor of Science in Chemical Engineering",
    "Bachelor of Science in Biomedical Engineering",
]

sample_skills = {
    "Computer Science": ["Python", "Java", "C++", "Machine Learning", "Data Analysis"],
    "Mechanical Engineering": ["CAD", "SolidWorks", "Thermodynamics", "Structural Analysis"],
    "Electrical Engineering": ["Circuit Design", "Microcontrollers", "Power Systems"],
    "Chemical Engineering": ["Chemical Process Design", "Chemical Kinetics", "Mass Transfer"],
    "Biomedical Engineering": ["Biomaterials", "Medical Imaging", "Biomechanics"],
    
}


import random

def generate_experience(degree):
    
    experience_titles = {
        "Bachelor of Science in Computer Science": ["Software Developer", "Data Analyst"],
        "Bachelor of Science in Electrical Engineering": ["Electrical Engineer", "Systems Engineer"],
        "Bachelor of Science in Biomedical Engineering": ["Biomedical Engineer", "Clinical Engineer"],
        "Bachelor of Engineering in Mechanical Engineering": ["Mechanical Engineer", "Design Engineer"],
        "Bachelor of Science in Chemical Engineering": ["Chemical Engineer", "Process Engineer"],
        
    }

    # List to hold experience
    experiences = []

    # Generate a random number of experiences (1 to 3 for this example)
    num_experiences = random.randint(1, 3)

    for _ in range(num_experiences):
        title = random.choice(experience_titles.get(degree, ["General Position"]))
        duration = f"{random.randint(1, 5)} years"  # Random duration between 1 to 5 years

        experiences.append({"title": title, "duration": duration})

    return experiences





# Function to generate a synthetic resume
def generate_resume():
    # Randomly select a degree
    degree = random.choice(sample_degrees)
    
    # Extract the field from the degree (splitting by 'in' and taking the last part)
    field = degree.split('in')[-1].strip()
    
    # Ensure the field is in sample_skills, or choose a random field if not found
    if field not in sample_skills:
        field = random.choice(list(sample_skills.keys()))
    
    # Randomly select skills for the resume, limiting the number of skills to 2-4
    num_skills = random.randint(2, min(4, len(sample_skills[field])))
    skills = random.sample(sample_skills[field], k=num_skills)

    # Generate a synthetic resume with skills, experience, and education
    return {
        "Skills": skills,
        "Experience": generate_experience(degree),
        "Education": degree
    }

# Generate a list of synthetic resumes
num_of_resumes = 1000  # You can change this to generate more resumes
synthetic_resumes = [generate_resume() for _ in range(num_of_resumes)]

# Display the generated resumes
for resume in synthetic_resumes:
    print(resume)
# Out:
# {'Skills': ['Data Analysis', 'C++', 'Machine Learning', 'Python'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '4 years'}, {'title': 'Electrical Engineer', 'duration': '3 years'}, {'title': 'Electrical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Java', 'Data Analysis'], 'Experience': [{'title': 'Systems Engineer', 'duration': '3 years'}, {'title': 'Systems Engineer', 'duration': '3 years'}, {'title': 'Systems Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '3 years'}, {'title': 'Systems Engineer', 'duration': '3 years'}, {'title': 'Systems Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '3 years'}, {'title': 'Biomedical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Java', 'Machine Learning', 'Data Analysis', 'C++'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Java', 'Data Analysis', 'Python'], 'Experience': [{'title': 'Software Developer', 'duration': '5 years'}, {'title': 'Software Developer', 'duration': '1 years'}, {'title': 'Data Analyst', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Systems Engineer', 'duration': '2 years'}, {'title': 'Systems Engineer', 'duration': '4 years'}, {'title': 'Electrical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Chemical Process Design', 'Chemical Kinetics'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '4 years'}, {'title': 'Design Engineer', 'duration': '3 years'}, {'title': 'Design Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Thermodynamics', 'Structural Analysis'], 'Experience': [{'title': 'Process Engineer', 'duration': '2 years'}, {'title': 'Process Engineer', 'duration': '4 years'}, {'title': 'Process Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Process Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Thermodynamics', 'CAD'], 'Experience': [{'title': 'Design Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Process Design'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '2 years'}, {'title': 'Systems Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '2 years'}, {'title': 'Biomedical Engineer', 'duration': '1 years'}, {'title': 'Biomedical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Python', 'Machine Learning', 'Java', 'C++'], 'Experience': [{'title': 'Software Developer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Process Design', 'Chemical Kinetics'], 'Experience': [{'title': 'Process Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Java', 'Python', 'Data Analysis', 'Machine Learning'], 'Experience': [{'title': 'Software Developer', 'duration': '2 years'}, {'title': 'Software Developer', 'duration': '2 years'}, {'title': 'Data Analyst', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['CAD', 'Structural Analysis', 'SolidWorks'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '5 years'}, {'title': 'Systems Engineer', 'duration': '2 years'}, {'title': 'Electrical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Biomechanics', 'Biomaterials'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '1 years'}, {'title': 'Biomedical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Java', 'Machine Learning', 'Python'], 'Experience': [{'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Design Engineer', 'duration': '1 years'}, {'title': 'Design Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['C++', 'Python', 'Machine Learning', 'Java'], 'Experience': [{'title': 'Design Engineer', 'duration': '4 years'}, {'title': 'Design Engineer', 'duration': '5 years'}, {'title': 'Mechanical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['SolidWorks', 'Thermodynamics', 'Structural Analysis', 'CAD'], 'Experience': [{'title': 'Process Engineer', 'duration': '1 years'}, {'title': 'Process Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Biomechanics', 'Medical Imaging'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Python', 'C++', 'Machine Learning'], 'Experience': [{'title': 'Data Analyst', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['SolidWorks', 'CAD', 'Structural Analysis'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '4 years'}, {'title': 'Clinical Engineer', 'duration': '4 years'}, {'title': 'Clinical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Machine Learning', 'Java', 'Data Analysis'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '5 years'}, {'title': 'Process Engineer', 'duration': '1 years'}, {'title': 'Process Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Python', 'Java', 'Data Analysis'], 'Experience': [{'title': 'Design Engineer', 'duration': '1 years'}, {'title': 'Design Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['C++', 'Java', 'Data Analysis'], 'Experience': [{'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Mechanical Engineer', 'duration': '3 years'}, {'title': 'Mechanical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Systems Engineer', 'duration': '4 years'}, {'title': 'Electrical Engineer', 'duration': '3 years'}, {'title': 'Systems Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Machine Learning', 'Java', 'C++'], 'Experience': [{'title': 'Data Analyst', 'duration': '3 years'}, {'title': 'Software Developer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['SolidWorks', 'Structural Analysis'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['CAD', 'Structural Analysis', 'Thermodynamics', 'SolidWorks'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Python', 'Data Analysis'], 'Experience': [{'title': 'Software Developer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Machine Learning', 'Java'], 'Experience': [{'title': 'Data Analyst', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Structural Analysis', 'Thermodynamics', 'CAD', 'SolidWorks'], 'Experience': [{'title': 'Process Engineer', 'duration': '2 years'}, {'title': 'Process Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Process Engineer', 'duration': '2 years'}, {'title': 'Process Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['CAD', 'Structural Analysis', 'SolidWorks', 'Thermodynamics'], 'Experience': [{'title': 'Design Engineer', 'duration': '3 years'}, {'title': 'Mechanical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomechanics'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '2 years'}, {'title': 'Chemical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Thermodynamics', 'SolidWorks', 'CAD', 'Structural Analysis'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Data Analysis', 'C++', 'Python', 'Machine Learning'], 'Experience': [{'title': 'Software Developer', 'duration': '1 years'}, {'title': 'Data Analyst', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Python', 'Data Analysis', 'Java', 'Machine Learning'], 'Experience': [{'title': 'Software Developer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '2 years'}, {'title': 'Clinical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Thermodynamics', 'SolidWorks'], 'Experience': [{'title': 'Systems Engineer', 'duration': '3 years'}, {'title': 'Electrical Engineer', 'duration': '3 years'}, {'title': 'Electrical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Machine Learning', 'C++'], 'Experience': [{'title': 'Design Engineer', 'duration': '5 years'}, {'title': 'Design Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Python', 'C++'], 'Experience': [{'title': 'Software Developer', 'duration': '5 years'}, {'title': 'Software Developer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Design Engineer', 'duration': '4 years'}, {'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Mechanical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Systems Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '3 years'}, {'title': 'Biomedical Engineer', 'duration': '4 years'}, {'title': 'Biomedical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Thermodynamics', 'Structural Analysis', 'SolidWorks', 'CAD'], 'Experience': [{'title': 'Design Engineer', 'duration': '4 years'}, {'title': 'Mechanical Engineer', 'duration': '4 years'}, {'title': 'Design Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Data Analysis', 'Java', 'C++'], 'Experience': [{'title': 'Data Analyst', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Structural Analysis', 'Thermodynamics', 'CAD'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '1 years'}, {'title': 'Process Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '5 years'}, {'title': 'Process Engineer', 'duration': '2 years'}, {'title': 'Process Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['SolidWorks', 'Thermodynamics', 'CAD', 'Structural Analysis'], 'Experience': [{'title': 'Design Engineer', 'duration': '3 years'}, {'title': 'Mechanical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomechanics'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '3 years'}, {'title': 'Clinical Engineer', 'duration': '1 years'}, {'title': 'Clinical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Java', 'C++'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '1 years'}, {'title': 'Biomedical Engineer', 'duration': '1 years'}, {'title': 'Biomedical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '5 years'}, {'title': 'Systems Engineer', 'duration': '3 years'}, {'title': 'Systems Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Thermodynamics', 'SolidWorks'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '3 years'}, {'title': 'Process Engineer', 'duration': '2 years'}, {'title': 'Process Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Process Engineer', 'duration': '4 years'}, {'title': 'Chemical Engineer', 'duration': '1 years'}, {'title': 'Chemical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Data Analysis', 'C++', 'Java', 'Python'], 'Experience': [{'title': 'Data Analyst', 'duration': '3 years'}, {'title': 'Software Developer', 'duration': '3 years'}, {'title': 'Data Analyst', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['SolidWorks', 'CAD', 'Thermodynamics', 'Structural Analysis'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '2 years'}, {'title': 'Clinical Engineer', 'duration': '4 years'}, {'title': 'Clinical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '5 years'}, {'title': 'Systems Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '3 years'}, {'title': 'Electrical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '1 years'}, {'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Mechanical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['C++', 'Machine Learning'], 'Experience': [{'title': 'Software Developer', 'duration': '3 years'}, {'title': 'Data Analyst', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Thermodynamics', 'Structural Analysis'], 'Experience': [{'title': 'Design Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Python', 'Machine Learning', 'Java', 'Data Analysis'], 'Experience': [{'title': 'Software Developer', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Kinetics', 'Chemical Process Design'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '5 years'}, {'title': 'Electrical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Design Engineer', 'duration': '5 years'}, {'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Design Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['C++', 'Python', 'Java', 'Data Analysis'], 'Experience': [{'title': 'Data Analyst', 'duration': '2 years'}, {'title': 'Data Analyst', 'duration': '2 years'}, {'title': 'Software Developer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Java', 'Machine Learning'], 'Experience': [{'title': 'Systems Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Python', 'C++', 'Data Analysis'], 'Experience': [{'title': 'Data Analyst', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['SolidWorks', 'CAD', 'Structural Analysis'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '1 years'}, {'title': 'Clinical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Structural Analysis', 'CAD', 'SolidWorks', 'Thermodynamics'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '5 years'}, {'title': 'Biomedical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['CAD', 'SolidWorks', 'Thermodynamics', 'Structural Analysis'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '4 years'}, {'title': 'Clinical Engineer', 'duration': '5 years'}, {'title': 'Biomedical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Machine Learning', 'Python', 'Data Analysis'], 'Experience': [{'title': 'Design Engineer', 'duration': '5 years'}, {'title': 'Design Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '3 years'}, {'title': 'Biomedical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Thermodynamics', 'CAD'], 'Experience': [{'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Mechanical Engineer', 'duration': '3 years'}, {'title': 'Design Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Process Design', 'Chemical Kinetics'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '1 years'}, {'title': 'Design Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['C++', 'Data Analysis', 'Machine Learning', 'Python'], 'Experience': [{'title': 'Software Developer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Machine Learning', 'Python', 'C++', 'Data Analysis'], 'Experience': [{'title': 'Data Analyst', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Biomechanics', 'Biomaterials'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '1 years'}, {'title': 'Biomedical Engineer', 'duration': '2 years'}, {'title': 'Clinical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Java', 'Machine Learning'], 'Experience': [{'title': 'Data Analyst', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '3 years'}, {'title': 'Clinical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['CAD', 'Thermodynamics'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '5 years'}, {'title': 'Design Engineer', 'duration': '4 years'}, {'title': 'Design Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Java', 'Data Analysis'], 'Experience': [{'title': 'Process Engineer', 'duration': '3 years'}, {'title': 'Chemical Engineer', 'duration': '4 years'}, {'title': 'Process Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Python', 'Machine Learning', 'C++'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '4 years'}, {'title': 'Systems Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Java', 'C++', 'Data Analysis'], 'Experience': [{'title': 'Software Developer', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Systems Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Process Engineer', 'duration': '4 years'}, {'title': 'Process Engineer', 'duration': '5 years'}, {'title': 'Process Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['C++', 'Python', 'Java'], 'Experience': [{'title': 'Software Developer', 'duration': '3 years'}, {'title': 'Software Developer', 'duration': '2 years'}, {'title': 'Software Developer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Java', 'Python', 'Machine Learning'], 'Experience': [{'title': 'Software Developer', 'duration': '2 years'}, {'title': 'Software Developer', 'duration': '5 years'}, {'title': 'Software Developer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Circuit Design', 'Power Systems'], 'Experience': [{'title': 'Systems Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Data Analysis', 'Python', 'C++'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Python', 'Machine Learning'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Python', 'Java'], 'Experience': [{'title': 'Process Engineer', 'duration': '1 years'}, {'title': 'Chemical Engineer', 'duration': '3 years'}, {'title': 'Chemical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Python', 'Machine Learning'], 'Experience': [{'title': 'Design Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '2 years'}, {'title': 'Process Engineer', 'duration': '3 years'}, {'title': 'Process Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Biomechanics', 'Biomaterials'], 'Experience': [{'title': 'Process Engineer', 'duration': '1 years'}, {'title': 'Chemical Engineer', 'duration': '5 years'}, {'title': 'Chemical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Mass Transfer'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '1 years'}, {'title': 'Mechanical Engineer', 'duration': '3 years'}, {'title': 'Mechanical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Data Analysis', 'C++'], 'Experience': [{'title': 'Software Developer', 'duration': '5 years'}, {'title': 'Software Developer', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Data Analysis', 'Java'], 'Experience': [{'title': 'Data Analyst', 'duration': '4 years'}, {'title': 'Data Analyst', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Thermodynamics', 'Structural Analysis', 'CAD', 'SolidWorks'], 'Experience': [{'title': 'Systems Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Structural Analysis', 'SolidWorks', 'CAD'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '4 years'}, {'title': 'Mechanical Engineer', 'duration': '2 years'}, {'title': 'Design Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Process Engineer', 'duration': '2 years'}, {'title': 'Chemical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Thermodynamics', 'CAD', 'SolidWorks'], 'Experience': [{'title': 'Systems Engineer', 'duration': '1 years'}, {'title': 'Electrical Engineer', 'duration': '1 years'}, {'title': 'Systems Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Python', 'Data Analysis'], 'Experience': [{'title': 'Data Analyst', 'duration': '2 years'}, {'title': 'Data Analyst', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '5 years'}, {'title': 'Electrical Engineer', 'duration': '4 years'}, {'title': 'Electrical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Java', 'C++'], 'Experience': [{'title': 'Data Analyst', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '5 years'}, {'title': 'Clinical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Data Analysis', 'C++', 'Python', 'Java'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '3 years'}, {'title': 'Clinical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['CAD', 'SolidWorks', 'Structural Analysis'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Structural Analysis', 'CAD', 'Thermodynamics', 'SolidWorks'], 'Experience': [{'title': 'Systems Engineer', 'duration': '2 years'}, {'title': 'Electrical Engineer', 'duration': '5 years'}, {'title': 'Systems Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '2 years'}, {'title': 'Biomedical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['C++', 'Java', 'Python', 'Data Analysis'], 'Experience': [{'title': 'Software Developer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['CAD', 'Structural Analysis', 'SolidWorks'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '3 years'}, {'title': 'Mechanical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '4 years'}, {'title': 'Clinical Engineer', 'duration': '1 years'}, {'title': 'Biomedical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Java', 'C++'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '1 years'}, {'title': 'Mechanical Engineer', 'duration': '3 years'}, {'title': 'Mechanical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Structural Analysis', 'Thermodynamics', 'CAD', 'SolidWorks'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '2 years'}, {'title': 'Electrical Engineer', 'duration': '5 years'}, {'title': 'Electrical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Java', 'Data Analysis', 'Machine Learning'], 'Experience': [{'title': 'Data Analyst', 'duration': '3 years'}, {'title': 'Software Developer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Data Analysis', 'C++', 'Python'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '5 years'}, {'title': 'Process Engineer', 'duration': '3 years'}, {'title': 'Chemical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Systems Engineer', 'duration': '4 years'}, {'title': 'Systems Engineer', 'duration': '3 years'}, {'title': 'Systems Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'Experience': [{'title': 'Process Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Python', 'Java'], 'Experience': [{'title': 'Software Developer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['CAD', 'Structural Analysis'], 'Experience': [{'title': 'Process Engineer', 'duration': '4 years'}, {'title': 'Chemical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '1 years'}, {'title': 'Biomedical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['C++', 'Python'], 'Experience': [{'title': 'Systems Engineer', 'duration': '5 years'}, {'title': 'Electrical Engineer', 'duration': '2 years'}, {'title': 'Electrical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['C++', 'Python'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['C++', 'Machine Learning', 'Data Analysis'], 'Experience': [{'title': 'Data Analyst', 'duration': '3 years'}, {'title': 'Data Analyst', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Java', 'Machine Learning'], 'Experience': [{'title': 'Data Analyst', 'duration': '1 years'}, {'title': 'Data Analyst', 'duration': '3 years'}, {'title': 'Data Analyst', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Machine Learning', 'Data Analysis'], 'Experience': [{'title': 'Software Developer', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Structural Analysis', 'SolidWorks', 'CAD', 'Thermodynamics'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '4 years'}, {'title': 'Clinical Engineer', 'duration': '4 years'}, {'title': 'Clinical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Thermodynamics', 'Structural Analysis'], 'Experience': [{'title': 'Design Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Machine Learning', 'Python', 'Java'], 'Experience': [{'title': 'Process Engineer', 'duration': '2 years'}, {'title': 'Chemical Engineer', 'duration': '5 years'}, {'title': 'Chemical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['C++', 'Machine Learning'], 'Experience': [{'title': 'Data Analyst', 'duration': '2 years'}, {'title': 'Data Analyst', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '5 years'}, {'title': 'Electrical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Thermodynamics', 'SolidWorks', 'CAD', 'Structural Analysis'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '4 years'}, {'title': 'Systems Engineer', 'duration': '5 years'}, {'title': 'Electrical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Biomechanics', 'Biomaterials'], 'Experience': [{'title': 'Process Engineer', 'duration': '3 years'}, {'title': 'Process Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Process Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['SolidWorks', 'Structural Analysis', 'CAD'], 'Experience': [{'title': 'Process Engineer', 'duration': '3 years'}, {'title': 'Process Engineer', 'duration': '1 years'}, {'title': 'Process Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Java', 'Python', 'C++'], 'Experience': [{'title': 'Software Developer', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '3 years'}, {'title': 'Data Analyst', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['CAD', 'Structural Analysis'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '1 years'}, {'title': 'Design Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Data Analysis', 'C++', 'Python'], 'Experience': [{'title': 'Data Analyst', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '5 years'}, {'title': 'Electrical Engineer', 'duration': '1 years'}, {'title': 'Systems Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Python', 'Java', 'C++', 'Machine Learning'], 'Experience': [{'title': 'Systems Engineer', 'duration': '4 years'}, {'title': 'Systems Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Biomechanics', 'Medical Imaging'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '5 years'}, {'title': 'Clinical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Structural Analysis', 'Thermodynamics'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '3 years'}, {'title': 'Process Engineer', 'duration': '1 years'}, {'title': 'Chemical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '5 years'}, {'title': 'Clinical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomechanics'], 'Experience': [{'title': 'Design Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Machine Learning', 'Python', 'Java', 'C++'], 'Experience': [{'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Design Engineer', 'duration': '4 years'}, {'title': 'Mechanical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['C++', 'Python'], 'Experience': [{'title': 'Software Developer', 'duration': '2 years'}, {'title': 'Software Developer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Java', 'C++'], 'Experience': [{'title': 'Software Developer', 'duration': '3 years'}, {'title': 'Data Analyst', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['SolidWorks', 'Structural Analysis', 'CAD', 'Thermodynamics'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '5 years'}, {'title': 'Design Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Process Design', 'Chemical Kinetics'], 'Experience': [{'title': 'Systems Engineer', 'duration': '4 years'}, {'title': 'Electrical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Systems Engineer', 'duration': '4 years'}, {'title': 'Systems Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['C++', 'Python', 'Machine Learning', 'Java'], 'Experience': [{'title': 'Data Analyst', 'duration': '1 years'}, {'title': 'Data Analyst', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '3 years'}, {'title': 'Design Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['SolidWorks', 'Structural Analysis', 'CAD'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '5 years'}, {'title': 'Process Engineer', 'duration': '5 years'}, {'title': 'Chemical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Structural Analysis', 'Thermodynamics', 'CAD', 'SolidWorks'], 'Experience': [{'title': 'Process Engineer', 'duration': '1 years'}, {'title': 'Process Engineer', 'duration': '4 years'}, {'title': 'Chemical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '3 years'}, {'title': 'Clinical Engineer', 'duration': '5 years'}, {'title': 'Biomedical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '5 years'}, {'title': 'Chemical Engineer', 'duration': '3 years'}, {'title': 'Chemical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '4 years'}, {'title': 'Biomedical Engineer', 'duration': '4 years'}, {'title': 'Biomedical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomechanics'], 'Experience': [{'title': 'Process Engineer', 'duration': '1 years'}, {'title': 'Chemical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['C++', 'Data Analysis', 'Python', 'Java'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '2 years'}, {'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Mechanical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Thermodynamics', 'SolidWorks', 'CAD'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['C++', 'Python', 'Machine Learning', 'Java'], 'Experience': [{'title': 'Data Analyst', 'duration': '1 years'}, {'title': 'Software Developer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Design Engineer', 'duration': '1 years'}, {'title': 'Mechanical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Python', 'C++', 'Java'], 'Experience': [{'title': 'Systems Engineer', 'duration': '4 years'}, {'title': 'Electrical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Python', 'Java', 'Data Analysis'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '3 years'}, {'title': 'Systems Engineer', 'duration': '1 years'}, {'title': 'Systems Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Python', 'Data Analysis'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Design Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Java', 'C++', 'Python', 'Machine Learning'], 'Experience': [{'title': 'Software Developer', 'duration': '2 years'}, {'title': 'Data Analyst', 'duration': '3 years'}, {'title': 'Software Developer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Machine Learning', 'Data Analysis'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '1 years'}, {'title': 'Design Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Machine Learning', 'Python', 'C++', 'Data Analysis'], 'Experience': [{'title': 'Software Developer', 'duration': '2 years'}, {'title': 'Software Developer', 'duration': '5 years'}, {'title': 'Software Developer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '4 years'}, {'title': 'Mechanical Engineer', 'duration': '4 years'}, {'title': 'Mechanical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Structural Analysis', 'Thermodynamics'], 'Experience': [{'title': 'Systems Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Design Engineer', 'duration': '1 years'}, {'title': 'Design Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Data Analysis', 'Python', 'Machine Learning', 'C++'], 'Experience': [{'title': 'Data Analyst', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '3 years'}, {'title': 'Software Developer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Python', 'Machine Learning', 'C++'], 'Experience': [{'title': 'Software Developer', 'duration': '2 years'}, {'title': 'Data Analyst', 'duration': '5 years'}, {'title': 'Software Developer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# ...
# {'Skills': ['Data Analysis', 'Java', 'Python', 'Machine Learning'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '1 years'}, {'title': 'Clinical Engineer', 'duration': '2 years'}, {'title': 'Biomedical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Data Analysis', 'Python', 'Java', 'C++'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '4 years'}, {'title': 'Chemical Engineer', 'duration': '1 years'}, {'title': 'Chemical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Python', 'Java', 'Data Analysis', 'C++'], 'Experience': [{'title': 'Software Developer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Data Analysis', 'Machine Learning', 'C++', 'Python'], 'Experience': [{'title': 'Data Analyst', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Medical Imaging', 'Biomechanics'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '5 years'}, {'title': 'Clinical Engineer', 'duration': '4 years'}, {'title': 'Biomedical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Python', 'C++'], 'Experience': [{'title': 'Data Analyst', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['C++', 'Python'], 'Experience': [{'title': 'Systems Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Data Analysis', 'Java'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '1 years'}, {'title': 'Clinical Engineer', 'duration': '2 years'}, {'title': 'Biomedical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Structural Analysis', 'SolidWorks'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '2 years'}, {'title': 'Electrical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Machine Learning', 'C++', 'Data Analysis'], 'Experience': [{'title': 'Data Analyst', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Systems Engineer', 'duration': '3 years'}, {'title': 'Electrical Engineer', 'duration': '5 years'}, {'title': 'Electrical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Thermodynamics', 'Structural Analysis', 'SolidWorks'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '1 years'}, {'title': 'Biomedical Engineer', 'duration': '1 years'}, {'title': 'Biomedical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'Experience': [{'title': 'Process Engineer', 'duration': '5 years'}, {'title': 'Process Engineer', 'duration': '1 years'}, {'title': 'Process Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomechanics'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '2 years'}, {'title': 'Clinical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['SolidWorks', 'Structural Analysis', 'Thermodynamics', 'CAD'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '5 years'}, {'title': 'Mechanical Engineer', 'duration': '5 years'}, {'title': 'Design Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['CAD', 'SolidWorks', 'Thermodynamics', 'Structural Analysis'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '3 years'}, {'title': 'Clinical Engineer', 'duration': '4 years'}, {'title': 'Clinical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Design Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Structural Analysis', 'Thermodynamics', 'CAD'], 'Experience': [{'title': 'Systems Engineer', 'duration': '3 years'}, {'title': 'Electrical Engineer', 'duration': '1 years'}, {'title': 'Electrical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Process Engineer', 'duration': '1 years'}, {'title': 'Process Engineer', 'duration': '4 years'}, {'title': 'Chemical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Design Engineer', 'duration': '4 years'}, {'title': 'Design Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Process Design', 'Chemical Kinetics'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '4 years'}, {'title': 'Electrical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '5 years'}, {'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Design Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Data Analysis', 'Machine Learning', 'C++'], 'Experience': [{'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Mechanical Engineer', 'duration': '1 years'}, {'title': 'Mechanical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '2 years'}, {'title': 'Clinical Engineer', 'duration': '5 years'}, {'title': 'Biomedical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['CAD', 'Structural Analysis', 'Thermodynamics', 'SolidWorks'], 'Experience': [{'title': 'Systems Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['CAD', 'SolidWorks', 'Thermodynamics'], 'Experience': [{'title': 'Process Engineer', 'duration': '5 years'}, {'title': 'Process Engineer', 'duration': '1 years'}, {'title': 'Chemical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['C++', 'Data Analysis'], 'Experience': [{'title': 'Data Analyst', 'duration': '3 years'}, {'title': 'Software Developer', 'duration': '4 years'}, {'title': 'Data Analyst', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Electrical Engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Data Analysis', 'Machine Learning'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Data Analysis', 'Python', 'Machine Learning', 'Java'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '1 years'}, {'title': 'Mechanical Engineer', 'duration': '3 years'}, {'title': 'Mechanical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Python', 'Machine Learning', 'Data Analysis', 'Java'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '5 years'}, {'title': 'Biomedical Engineer', 'duration': '3 years'}, {'title': 'Clinical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Machine Learning', 'Python'], 'Experience': [{'title': 'Process Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Circuit Design', 'Microcontrollers', 'Power Systems'], 'Experience': [{'title': 'Design Engineer', 'duration': '5 years'}, {'title': 'Design Engineer', 'duration': '2 years'}, {'title': 'Mechanical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Chemical Process Design'], 'Experience': [{'title': 'Design Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Data Analysis', 'C++', 'Machine Learning', 'Python'], 'Experience': [{'title': 'Data Analyst', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Python', 'Machine Learning', 'Data Analysis', 'Java'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Circuit Design', 'Microcontrollers', 'Power Systems'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '1 years'}, {'title': 'Process Engineer', 'duration': '4 years'}, {'title': 'Chemical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Java', 'Python', 'C++', 'Data Analysis'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '5 years'}, {'title': 'Design Engineer', 'duration': '4 years'}, {'title': 'Mechanical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Python', 'C++', 'Data Analysis'], 'Experience': [{'title': 'Data Analyst', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Java', 'C++', 'Python'], 'Experience': [{'title': 'Data Analyst', 'duration': '2 years'}, {'title': 'Software Developer', 'duration': '4 years'}, {'title': 'Data Analyst', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '2 years'}, {'title': 'Biomedical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Structural Analysis', 'Thermodynamics', 'CAD', 'SolidWorks'], 'Experience': [{'title': 'Design Engineer', 'duration': '3 years'}, {'title': 'Mechanical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '1 years'}, {'title': 'Process Engineer', 'duration': '5 years'}, {'title': 'Process Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['C++', 'Java', 'Data Analysis', 'Python'], 'Experience': [{'title': 'Systems Engineer', 'duration': '4 years'}, {'title': 'Systems Engineer', 'duration': '5 years'}, {'title': 'Systems Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Java', 'Machine Learning', 'C++', 'Data Analysis'], 'Experience': [{'title': 'Process Engineer', 'duration': '4 years'}, {'title': 'Chemical Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Machine Learning', 'Data Analysis'], 'Experience': [{'title': 'Data Analyst', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Data Analysis', 'C++', 'Python'], 'Experience': [{'title': 'Systems Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['SolidWorks', 'Structural Analysis', 'CAD'], 'Experience': [{'title': 'Systems Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Data Analysis', 'Machine Learning'], 'Experience': [{'title': 'Systems Engineer', 'duration': '3 years'}, {'title': 'Systems Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Python', 'C++'], 'Experience': [{'title': 'Software Developer', 'duration': '4 years'}, {'title': 'Software Developer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Circuit Design', 'Power Systems'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '3 years'}, {'title': 'Clinical Engineer', 'duration': '3 years'}, {'title': 'Clinical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Machine Learning', 'Data Analysis'], 'Experience': [{'title': 'Data Analyst', 'duration': '1 years'}, {'title': 'Software Developer', 'duration': '1 years'}, {'title': 'Data Analyst', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'Experience': [{'title': 'Mechanical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Systems Engineer', 'duration': '2 years'}, {'title': 'Electrical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Biomedical Engineer', 'duration': '5 years'}, {'title': 'Clinical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['C++', 'Java', 'Python'], 'Experience': [{'title': 'Software Developer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Clinical Engineer', 'duration': '1 years'}, {'title': 'Clinical Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Python', 'Machine Learning', 'C++', 'Java'], 'Experience': [{'title': 'Design Engineer', 'duration': '3 years'}, {'title': 'Mechanical Engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Machine Learning', 'Python'], 'Experience': [{'title': 'Process Engineer', 'duration': '2 years'}, {'title': 'Chemical Engineer', 'duration': '2 years'}, {'title': 'Process Engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Process Engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Chemical Engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}

# %%
def extract_keywords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    keywords = [word for word in word_tokens if word.isalpha() and word not in stop_words]
    return keywords


def extract_keywords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    keywords = [word for word in word_tokens if word.isalpha() and word not in stop_words]
    return keywords


for job in jobs_data:
    job['keywords'] = extract_keywords(' '.join(job['required_skills']) + ' ' + job['experience_title'] + ' ' + job['required_education'])

for resume in synthetic_resumes:
    resume['keywords'] = extract_keywords(' '.join(resume['Skills']) + ' ' + ' '.join([exp['title'] for exp in resume['Experience']]) + ' ' + resume['Education'])

    def match_score(job_keywords, resume_keywords):
     return len(set(job_keywords) & set(resume_keywords))

matches = []
for resume in synthetic_resumes:
    for job in jobs_data:
        score = match_score(job['keywords'], resume['keywords'])
        matches.append((score, job, resume))

# Sort matches based on score
matches.sort(reverse=True, key=lambda x: x[0])


for score, job, resume in matches[:500]:  # Display top 10 matches
    print(f"Match Score: {score}\nJob: {job['experience_title']}\nResume: {resume['Experience'][0]['title']}\n")
# Out:
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical biochemist
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Clinical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Chemical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Biomedical Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, civil (contracting)
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, aeronautical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electronics
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Systems Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Electrical Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, technical sales
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, biomedical
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Process Engineer
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Process Engineer
#
# Match Score: 9
# Job: Lecturer, further education
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Retail merchandiser
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Programmer, systems
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Office manager
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Administrator, education
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Structural engineer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Runner, broadcasting/film/video
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Licensed conveyancer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Mental health nurse
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Radiographer, diagnostic
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Public affairs consultant
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Therapist, art
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Phytotherapist
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Print production planner
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Animal nutritionist
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Oceanographer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Analytical chemist
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Radio broadcast assistant
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Transport planner
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Conservator, furniture
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Psychologist, clinical
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Academic librarian
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Surveyor, commercial/residential
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Journalist, broadcasting
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Race relations officer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Merchandiser, retail
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Educational psychologist
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Nurse, learning disability
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Public affairs consultant
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Special educational needs teacher
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Sports administrator
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Sports therapist
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Recruitment consultant
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Accountant, chartered public finance
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Sales professional, IT
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Landscape architect
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Microbiologist
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Forest/woodland manager
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Land
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Public librarian
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Civil Service administrator
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Audiological scientist
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Health service manager
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Clothing/textile technologist
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Fast food restaurant manager
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Information systems manager
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Education officer, community
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Purchasing manager
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Lawyer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Civil Service fast streamer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Trade mark attorney
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Pilot, airline
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Industrial buyer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Teaching laboratory technician
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Local government officer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Production assistant, radio
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Recycling officer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Contractor
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Occupational hygienist
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Chartered certified accountant
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Site engineer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Producer, television/film/video
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Radio broadcast assistant
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Aeronautical engineer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Bookseller
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Company secretary
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Teacher, special educational needs
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Meteorologist
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Nature conservation officer
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Video editor
# Resume: Biomedical Engineer
#
# Match Score: 9
# Job: Forest/woodland manager
# Resume: Biomedical Engineer

# %%
resume_mapping = {
    "settings": {
        "analysis": {
            "analyzer": {
                "custom_analyzer": {
                    "type": "custom",
                    "tokenizer": "whitespace",
                    "filter": ["lowercase"]
                }
            }
        }
    },
    "mappings": {
        "properties": {
            "Skills": {"type": "text", "analyzer": "custom_analyzer"},
            "Experience": {
                "type": "nested",
                "properties": {
                    "title": {"type": "text", "analyzer": "custom_analyzer"},
                    "duration": {"type": "text", "analyzer": "custom_analyzer"}
                }
            },
            "Education": {"type": "text", "analyzer": "custom_analyzer"}
        }
    }
}

# %%
from elasticsearch import Elasticsearch

# Connect to Elasticsearch
es = Elasticsearch("http://localhost:9200")

# Define custom analyzer (if needed)
custom_analyzer = {
    "analyzer": {
        "custom_lowercase_analyzer": {
            "type": "custom",
            "tokenizer": "standard",
            "filter": ["lowercase"]
        }
    }
}

# Define mapping for job listing index
job_mapping = {
    "settings": {
        "analysis": {
            "analyzer": {
                "custom_lowercase_analyzer": {
                    "type": "custom",
                    "tokenizer": "standard",
                    "filter": ["lowercase"]
                }
            }
        }
    },
    "mappings": {
        "properties": {
            "required_skills": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "experience_title": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "required_education": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "keywords": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "provider": {"type": "text", "analyzer": "custom_lowercase_analyzer"}  # New field
        }
    }
}

resume_mapping = {
    "settings": custom_analyzer,
    "mappings": {
        "properties": {
            "skills": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "experience": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "education": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "keywords": {"type": "text", "analyzer": "custom_lowercase_analyzer"}
        }
    }
}

# %%
from elasticsearch import Elasticsearch, helpers

es = Elasticsearch("http://localhost:9200")



def job_data_generator(job_data):
    for job in job_data:
        yield {
            "_index": "job_listings",
            "_id": job.get("id"),
            "_source": job
        }

es.indices.delete(index='job_listings', ignore=[400, 404])

# Create the new index with the updated mapping
es.indices.create(index='job_listings', body=job_mapping)

# Re-index your job data
helpers.bulk(es, job_data_generator(jobs_data))





# Function to create a generator yielding resume data for bulk indexing
def resume_data_generator(resume_data):
    for resume in resume_data:
        yield {
            "_index": "resumes",
            "_id": resume.get("id"),  # Assuming each resume has a unique 'id' field
            "_source": resume
        }





# Bulk indexing resume data
helpers.bulk(es, resume_data_generator(synthetic_resumes))

print("Indexing complete.")
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_15852\1501628427.py:15: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   es.indices.delete(index='job_listings', ignore=[400, 404])
# C:\Users\acer\AppData\Local\Temp\ipykernel_15852\1501628427.py:15: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.15/security-minimal-setup.html to enable security.
#   es.indices.delete(index='job_listings', ignore=[400, 404])
# C:\Users\acer\AppData\Local\Temp\ipykernel_15852\1501628427.py:18: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.15/security-minimal-setup.html to enable security.
#   es.indices.create(index='job_listings', body=job_mapping)
# C:\Users\acer\AppData\Local\Temp\ipykernel_15852\1501628427.py:21: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.15/security-minimal-setup.html to enable security.
#   helpers.bulk(es, job_data_generator(jobs_data))
# C:\Users\acer\AppData\Local\Temp\ipykernel_15852\1501628427.py:41: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.15/security-minimal-setup.html to enable security.
#   helpers.bulk(es, resume_data_generator(synthetic_resumes))
# Indexing complete.

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch("http://localhost:9200")

input_resume = {
    "skills": ['CAD', 'Thermodynamics', 'SolidWorks'],  # Relevant skills for mechanical engineering
    "education": "Bachelor's in Mechanical Engineering",
    "experience": "Mechanical Design"  # Optional: Include if experience titles are relevant
}


# Formulate a more targeted but not overly complex search query
query_body = {
    "query": {
        "bool": {
            "should": [
                {"match": {"required_skills": {"query": skill, "boost": 1.2}} for skill in input_resume["skills"]},
                {"match_phrase": {"required_education": input_resume["education"]}},
                # Optional: Include if experience titles are relevant
                {"match": {"experience_title": input_resume["experience"]}}
            ],
            "minimum_should_match": 1
        }
    },
    "size": 10  # Adjust the number of results as needed
}

# Search the job listings index
results = es.search(index="job_listings", body=query_body)

# Print the matched job listings
print("Matched Job Listings:")
for hit in results['hits']['hits']:
    job_listing = hit['_source']
    provider = job_listing.get('provider', 'Unknown Provider')  # Default to 'Unknown Provider' if not present
    print(f"Job Title: {job_listing['experience_title']}, Provider: {job_listing.get('provider', 'Unknown')}, Score: {hit['_score']}")
# Out:
# Matched Job Listings:
# Job Title: Mechanical engineer, Provider: Provider U, Score: 6.9844527
# Job Title: Programmer, applications, Provider: Provider V, Score: 3.003996
# Job Title: Commercial art gallery manager, Provider: Provider Z, Score: 3.003996
# Job Title: Agricultural engineer, Provider: Provider T, Score: 3.003996
# Job Title: Intelligence analyst, Provider: Provider D, Score: 3.003996
# Job Title: Solicitor, Scotland, Provider: Provider B, Score: 3.003996
# Job Title: Community education officer, Provider: Provider K, Score: 3.003996
# Job Title: Warden/ranger, Provider: Provider R, Score: 3.003996
# Job Title: Materials engineer, Provider: Provider U, Score: 3.003996
# Job Title: Tourist information centre manager, Provider: Provider L, Score: 3.003996
# C:\Users\acer\AppData\Local\Temp\ipykernel_15852\2118377580.py:29: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.15/security-minimal-setup.html to enable security.
#   results = es.search(index="job_listings", body=query_body)

# %%
"""
Project Title: Job Matching and Visualization

Problem Statement:
As part of this project, we aim to develop a system that efficiently matches job listings with resumes based on skills, experience, and education. 

Solution Overview:
To address this problem, we will implement a multi-step approach:
1. Data Preparation: We'll gather job listings and resumes data and preprocess it for indexing.
2. Indexing: We'll index the preprocessed data into Elasticsearch, a highly scalable search engine.
3. Matching Algorithm: We'll develop an algorithm to match resumes with job listings based on key criteria such as skills, experience, and education.


Approach:
- Utilize Python and Elasticsearch for data preprocessing, indexing, and matching.
- Implement NLP techniques for feature extraction and keyword matching.
- Test and iterate on the matching algorithm to improve accuracy and efficiency.
- Document each step and provide clear explanations for transparency and reproducibility.
"""
# Out:
# "\nProject Title: Job Matching and Visualization\n\nProblem Statement:\nAs part of this project, we aim to develop a system that efficiently matches job listings with resumes based on skills, experience, and education. \n\nSolution Overview:\nTo address this problem, we will implement a multi-step approach:\n1. Data Preparation: We'll gather job listings and resumes data and preprocess it for indexing.\n2. Indexing: We'll index the preprocessed data into Elasticsearch, a highly scalable search engine.\n3. Matching Algorithm: We'll develop an algorithm to match resumes with job listings based on key criteria such as skills, experience, and education.\n\n\nApproach:\n- Utilize Python and Elasticsearch for data preprocessing, indexing, and matching.\n- Implement NLP techniques for feature extraction and keyword matching.\n- Test and iterate on the matching algorithm to improve accuracy and efficiency.\n- Document each step and provide clear explanations for transparency and reproducibility.\n"

# %%
pip install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (8.12.0)
# Requirement already satisfied: elastic-transport<9,>=8 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from elasticsearch) (8.12.0)
# Requirement already satisfied: urllib3<3,>=1.26.2 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from elastic-transport<9,>=8->elasticsearch) (2.0.7)
# Requirement already satisfied: certifi in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from elastic-transport<9,>=8->elasticsearch) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
"""
Generate Fake Job Data using Faker

This section generates synthetic job data using the Faker library while considering specific aspects required for the job data. Faker is a Python library that generates fake data such as names, addresses, and job titles, which is useful for creating realistic but synthetic datasets for testing and development purposes.

In this script, we'll use Faker to generate job-related data for various fields such as required_skills, experience_title, and required_education. We'll ensure that the generated job data aligns with certain aspects, such as the required skills, experience titles, and required education levels specified by the user.

By using Faker, we can easily create large volumes of diverse job data that closely resemble real-world job listings. This synthetic data will be useful for testing the matching algorithm and visualizing the job data in Kibana.

"""
# Out:
# "\nGenerate Fake Job Data using Faker\n\nThis section generates synthetic job data using the Faker library while considering specific aspects required for the job data. Faker is a Python library that generates fake data such as names, addresses, and job titles, which is useful for creating realistic but synthetic datasets for testing and development purposes.\n\nIn this script, we'll use Faker to generate job-related data for various fields such as required_skills, experience_title, and required_education. We'll ensure that the generated job data aligns with certain aspects, such as the required skills, experience titles, and required education levels specified by the user.\n\nBy using Faker, we can easily create large volumes of diverse job data that closely resemble real-world job listings. This synthetic data will be useful for testing the matching algorithm and visualizing the job data in Kibana.\n\n"

# %%
from faker import Faker
import random

fake = Faker()

# Provided sample skills and degrees
sample_skills = {
    "Computer Science": ["Python", "Java", "C++", "Machine Learning", "Data Analysis"],
    "Mechanical Engineering": ["CAD", "SolidWorks", "Thermodynamics", "Structural Analysis"],
    "Electrical Engineering": ["Circuit Design", "Microcontrollers", "Power Systems"],
    "Chemical Engineering": ["Chemical Process Design", "Chemical Kinetics", "Mass Transfer"],
    "Biomedical Engineering": ["Biomaterials", "Medical Imaging", "Biomechanics"],
}

sample_degrees = [
    "Bachelor of Science in Computer Science",
    "Bachelor of Engineering in Mechanical Engineering",
    "Bachelor of Science in Electrical Engineering",
    "Bachelor of Science in Chemical Engineering",
    "Bachelor of Science in Biomedical Engineering",
]

degree_to_field = {
    "Bachelor of Science in Computer Science": "Computer Science",
    "Bachelor of Engineering in Mechanical Engineering": "Mechanical Engineering",
    "Bachelor of Science in Electrical Engineering": "Electrical Engineering",
    "Bachelor of Science in Chemical Engineering": "Chemical Engineering",
    "Bachelor of Science in Biomedical Engineering": "Biomedical Engineering",
}

def generate_job_data(num_jobs=10):
    job_data = []
    for _ in range(num_jobs):
        degree = random.choice(sample_degrees)
        field = degree_to_field[degree]
        num_skills = len(sample_skills[field])
        num_skills_to_sample = min(random.randint(2, 4), num_skills)

        job = {
            "required_skills": random.sample(sample_skills[field], k=num_skills_to_sample),
            "experience_title": fake.job(),
            "required_education": degree
        }
        job_data.append(job)
    
    return job_data

# Generate job data
jobs_data = generate_job_data(1000)

# Display a few generated job data
for job in jobs_data[:10]:
    print(job)

import string

def generate_provider_name(index):
    # Generates provider names like 'Provider A', 'Provider B', ...
    return f"Provider {string.ascii_uppercase[index % 26]}"

# Add a 'provider' field to each job
for index, job in enumerate(jobs_data):
    job['provider'] = generate_provider_name(index)

# Example: Print the first 10 jobs to see the provider names
for job in jobs_data[:1000]:
    print(job)
# Out:
# {'required_skills': ['SolidWorks', 'Thermodynamics', 'CAD'], 'experience_title': 'IT technical support officer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'required_skills': ['Biomaterials', 'Medical Imaging'], 'experience_title': 'Secretary/administrator', 'required_education': 'Bachelor of Science in Biomedical Engineering'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Administrator, arts', 'required_education': 'Bachelor of Science in Chemical Engineering'}
# {'required_skills': ['Medical Imaging', 'Biomaterials'], 'experience_title': 'Designer, fashion/clothing', 'required_education': 'Bachelor of Science in Biomedical Engineering'}
# {'required_skills': ['Java', 'C++', 'Data Analysis', 'Python'], 'experience_title': 'Therapist, nutritional', 'required_education': 'Bachelor of Science in Computer Science'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Pilot, airline', 'required_education': 'Bachelor of Science in Chemical Engineering'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Midwife', 'required_education': 'Bachelor of Science in Chemical Engineering'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Publishing copy', 'required_education': 'Bachelor of Science in Chemical Engineering'}
# {'required_skills': ['Power Systems', 'Circuit Design'], 'experience_title': 'Systems analyst', 'required_education': 'Bachelor of Science in Electrical Engineering'}
# {'required_skills': ['Java', 'C++', 'Machine Learning'], 'experience_title': 'Petroleum engineer', 'required_education': 'Bachelor of Science in Computer Science'}
# {'required_skills': ['SolidWorks', 'Thermodynamics', 'CAD'], 'experience_title': 'IT technical support officer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Biomaterials', 'Medical Imaging'], 'experience_title': 'Secretary/administrator', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Administrator, arts', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Medical Imaging', 'Biomaterials'], 'experience_title': 'Designer, fashion/clothing', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Java', 'C++', 'Data Analysis', 'Python'], 'experience_title': 'Therapist, nutritional', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider E'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Pilot, airline', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Midwife', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Publishing copy', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Power Systems', 'Circuit Design'], 'experience_title': 'Systems analyst', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Java', 'C++', 'Machine Learning'], 'experience_title': 'Petroleum engineer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider J'}
# {'required_skills': ['Java', 'Data Analysis', 'C++', 'Python'], 'experience_title': 'Press sub', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider K'}
# {'required_skills': ['Machine Learning', 'C++', 'Java'], 'experience_title': 'Medical illustrator', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider L'}
# {'required_skills': ['Thermodynamics', 'SolidWorks'], 'experience_title': 'Ceramics designer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Data Analysis', 'Machine Learning', 'Python'], 'experience_title': 'Geoscientist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider N'}
# {'required_skills': ['C++', 'Data Analysis'], 'experience_title': 'Special effects artist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider O'}
# {'required_skills': ['SolidWorks', 'Thermodynamics', 'Structural Analysis', 'CAD'], 'experience_title': 'Commercial horticulturist', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Java', 'Machine Learning', 'Data Analysis', 'C++'], 'experience_title': 'Psychologist, occupational', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Q'}
# {'required_skills': ['Microcontrollers', 'Circuit Design'], 'experience_title': 'Armed forces logistics/support/administrative officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Water engineer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Circuit Design', 'Microcontrollers'], 'experience_title': 'Chartered management accountant', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'Solicitor, Scotland', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'Passenger transport manager', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Cytogeneticist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Machine Learning', 'Java', 'Data Analysis'], 'experience_title': 'Travel agency manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider X'}
# {'required_skills': ['Structural Analysis', 'CAD', 'Thermodynamics', 'SolidWorks'], 'experience_title': 'Horticultural consultant', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Python', 'Data Analysis', 'Machine Learning'], 'experience_title': 'Occupational hygienist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Z'}
# {'required_skills': ['C++', 'Machine Learning', 'Python'], 'experience_title': 'Optometrist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider A'}
# {'required_skills': ['Java', 'C++', 'Machine Learning', 'Python'], 'experience_title': 'Conservator, furniture', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider B'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Illustrator', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Soil scientist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Production designer, theatre/television/film', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['CAD', 'Thermodynamics'], 'experience_title': 'Environmental consultant', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Museum/gallery conservator', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Java', 'Machine Learning', 'C++', 'Python'], 'experience_title': 'Intelligence analyst', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider H'}
# {'required_skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'experience_title': 'Physiotherapist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Clinical embryologist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Biomaterials', 'Medical Imaging'], 'experience_title': 'Dramatherapist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Haematologist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Telecommunications researcher', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Thermodynamics', 'CAD', 'SolidWorks'], 'experience_title': 'Communications engineer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Cabin crew', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Armed forces logistics/support/administrative officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['SolidWorks', 'Structural Analysis', 'Thermodynamics', 'CAD'], 'experience_title': 'Dietitian', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'experience_title': 'Sports development officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Site engineer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Java', 'Python', 'Machine Learning', 'Data Analysis'], 'experience_title': 'Call centre manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider T'}
# {'required_skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'experience_title': 'Editor, magazine features', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Designer, textile', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Museum/gallery exhibitions officer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': "Barrister's clerk", 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Structural Analysis', 'CAD', 'SolidWorks', 'Thermodynamics'], 'experience_title': 'Information officer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Chief Marketing Officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Engineer, chemical', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'Physiological scientist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'experience_title': 'Chief Operating Officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Radiographer, diagnostic', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['CAD', 'Structural Analysis', 'SolidWorks'], 'experience_title': 'Scientist, research (physical sciences)', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Chartered loss adjuster', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Java', 'Machine Learning', 'Python', 'Data Analysis'], 'experience_title': 'Diagnostic radiographer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider G'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Customer service manager', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Structural Analysis', 'Thermodynamics', 'SolidWorks'], 'experience_title': 'Government social research officer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Python', 'Machine Learning'], 'experience_title': 'Programmer, multimedia', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider J'}
# {'required_skills': ['Python', 'C++', 'Data Analysis', 'Java'], 'experience_title': 'Theme park manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider K'}
# {'required_skills': ['Python', 'Data Analysis', 'C++', 'Java'], 'experience_title': 'Fitness centre manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider L'}
# {'required_skills': ['Circuit Design', 'Microcontrollers', 'Power Systems'], 'experience_title': 'Podiatrist', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['SolidWorks', 'CAD', 'Thermodynamics'], 'experience_title': 'Engineer, biomedical', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Medical Imaging', 'Biomaterials'], 'experience_title': 'Aid worker', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Structural engineer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Financial adviser', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Python', 'C++'], 'experience_title': 'Animator', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider R'}
# {'required_skills': ['Power Systems', 'Circuit Design'], 'experience_title': 'Engineer, energy', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Cartographer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Presenter, broadcasting', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Immigration officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Machine Learning', 'Data Analysis'], 'experience_title': 'Government social research officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider W'}
# {'required_skills': ['Java', 'Machine Learning', 'Python', 'C++'], 'experience_title': 'Probation officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider X'}
# {'required_skills': ['Thermodynamics', 'SolidWorks', 'CAD'], 'experience_title': 'Social research officer, government', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Power Systems', 'Microcontrollers'], 'experience_title': 'Glass blower/designer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Therapist, occupational', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Warden/ranger', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Data Analysis', 'C++'], 'experience_title': 'Financial adviser', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider C'}
# {'required_skills': ['CAD', 'SolidWorks'], 'experience_title': 'Immigration officer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['SolidWorks', 'Structural Analysis', 'CAD', 'Thermodynamics'], 'experience_title': 'Loss adjuster, chartered', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Medical Imaging', 'Biomechanics'], 'experience_title': 'Child psychotherapist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Biomechanics', 'Medical Imaging'], 'experience_title': 'Animal nutritionist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Java', 'Machine Learning', 'Data Analysis'], 'experience_title': 'Interpreter', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider H'}
# {'required_skills': ['Thermodynamics', 'Structural Analysis'], 'experience_title': 'Teacher, adult education', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Photographer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['SolidWorks', 'Thermodynamics'], 'experience_title': 'Environmental consultant', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Data Analysis', 'Python', 'Machine Learning'], 'experience_title': 'Armed forces technical officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider L'}
# {'required_skills': ['Biomaterials', 'Medical Imaging'], 'experience_title': 'Designer, interior/spatial', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['CAD', 'SolidWorks', 'Structural Analysis'], 'experience_title': 'Engineer, materials', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Data Analysis', 'Java'], 'experience_title': 'Print production planner', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider O'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'Barista', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Photographer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Engineer, materials', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Structural Analysis', 'Thermodynamics', 'SolidWorks', 'CAD'], 'experience_title': 'Fitness centre manager', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['CAD', 'SolidWorks', 'Thermodynamics'], 'experience_title': 'Operational investment banker', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Machine Learning', 'Java'], 'experience_title': 'Learning mentor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider U'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Printmaker', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Teacher, adult education', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Engineer, maintenance (IT)', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'experience_title': 'Horticulturist, amenity', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Python', 'C++', 'Java'], 'experience_title': 'Sports administrator', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Z'}
# {'required_skills': ['Biomaterials', 'Medical Imaging'], 'experience_title': 'Clinical research associate', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Engineer, water', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Horticultural consultant', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Estate manager/land agent', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Thermodynamics', 'CAD', 'SolidWorks'], 'experience_title': 'Theme park manager', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Community development worker', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Data Analysis', 'C++', 'Python'], 'experience_title': 'Management consultant', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider G'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Nature conservation officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'experience_title': 'Interpreter', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Data Analysis', 'C++'], 'experience_title': 'Herpetologist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider J'}
# {'required_skills': ['Biomaterials', 'Medical Imaging'], 'experience_title': 'Police officer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['SolidWorks', 'CAD', 'Structural Analysis'], 'experience_title': 'Early years teacher', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'Financial controller', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Structural Analysis', 'Thermodynamics', 'SolidWorks', 'CAD'], 'experience_title': 'Nutritional therapist', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['CAD', 'Structural Analysis'], 'experience_title': 'Phytotherapist', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Retail buyer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Psychotherapist, dance movement', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'English as a foreign language teacher', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Python', 'Machine Learning', 'Java', 'Data Analysis'], 'experience_title': 'Therapist, music', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider S'}
# {'required_skills': ['SolidWorks', 'Thermodynamics', 'CAD', 'Structural Analysis'], 'experience_title': 'Immunologist', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Circuit Design', 'Microcontrollers'], 'experience_title': 'Futures trader', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Airline pilot', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Diplomatic Services operational officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Insurance underwriter', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Machine Learning', 'Java', 'Python', 'C++'], 'experience_title': 'Higher education lecturer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Y'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Housing manager/officer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Thermodynamics', 'Structural Analysis', 'SolidWorks', 'CAD'], 'experience_title': 'Conservator, museum/gallery', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['SolidWorks', 'Thermodynamics', 'Structural Analysis', 'CAD'], 'experience_title': 'Presenter, broadcasting', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Armed forces technical officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Accountant, chartered management', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Data Analysis', 'Java', 'Machine Learning'], 'experience_title': 'Forensic scientist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider E'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Financial manager', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Circuit Design', 'Microcontrollers', 'Power Systems'], 'experience_title': 'Engineer, aeronautical', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Radiation protection practitioner', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'experience_title': 'Engineer, agricultural', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Accountant, chartered management', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['SolidWorks', 'Thermodynamics'], 'experience_title': 'IT consultant', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'Child psychotherapist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Power Systems', 'Microcontrollers'], 'experience_title': 'Amenity horticulturist', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Equities trader', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Ergonomist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Public house manager', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['CAD', 'Thermodynamics', 'SolidWorks'], 'experience_title': 'Landscape architect', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Scientist, product/process development', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'experience_title': 'Glass blower/designer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Medical Imaging', 'Biomaterials'], 'experience_title': 'Housing manager/officer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Medical Imaging', 'Biomechanics'], 'experience_title': 'Patent attorney', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Thermodynamics', 'SolidWorks', 'CAD', 'Structural Analysis'], 'experience_title': 'Hospital doctor', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Circuit Design', 'Microcontrollers'], 'experience_title': 'Engineer, control and instrumentation', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Circuit Design', 'Power Systems'], 'experience_title': 'Geologist, engineering', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['CAD', 'SolidWorks', 'Thermodynamics'], 'experience_title': 'Personnel officer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Machine Learning', 'C++', 'Java'], 'experience_title': 'Osteopath', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Z'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Production engineer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Java', 'Python', 'C++', 'Data Analysis'], 'experience_title': 'Environmental consultant', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider B'}
# {'required_skills': ['Java', 'Python', 'C++', 'Machine Learning'], 'experience_title': 'Clinical scientist, histocompatibility and immunogenetics', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider C'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Scientist, marine', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['C++', 'Data Analysis', 'Python', 'Java'], 'experience_title': 'Location manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider E'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Engineer, control and instrumentation', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Doctor, hospital', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Thermodynamics', 'SolidWorks'], 'experience_title': 'Therapist, art', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Orthoptist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'IT technical support officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Public librarian', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Prison officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['C++', 'Data Analysis', 'Python', 'Machine Learning'], 'experience_title': 'Engineer, land', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider M'}
# {'required_skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'experience_title': 'Presenter, broadcasting', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Clinical scientist, histocompatibility and immunogenetics', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Scientist, product/process development', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Machine Learning', 'C++', 'Python'], 'experience_title': 'Local government officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Q'}
# {'required_skills': ['Thermodynamics', 'SolidWorks', 'Structural Analysis'], 'experience_title': 'IT trainer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Homeopath', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Machine Learning', 'Data Analysis'], 'experience_title': 'Advertising account planner', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider T'}
# {'required_skills': ['Python', 'Machine Learning', 'C++', 'Data Analysis'], 'experience_title': 'Therapist, horticultural', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider U'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'Information officer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['SolidWorks', 'Structural Analysis', 'CAD'], 'experience_title': 'Exhibitions officer, museum/gallery', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Veterinary surgeon', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Occupational psychologist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Exhibitions officer, museum/gallery', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['SolidWorks', 'Structural Analysis', 'CAD', 'Thermodynamics'], 'experience_title': 'Interpreter', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Journalist, magazine', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Structural Analysis', 'SolidWorks', 'Thermodynamics', 'CAD'], 'experience_title': 'Pension scheme manager', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'experience_title': 'Technical sales engineer', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['C++', 'Java', 'Python', 'Machine Learning'], 'experience_title': 'Architect', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider E'}
# {'required_skills': ['C++', 'Python', 'Machine Learning'], 'experience_title': 'Immigration officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider F'}
# {'required_skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'experience_title': 'Designer, multimedia', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['CAD', 'Structural Analysis'], 'experience_title': 'Barista', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Exhibition designer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Research scientist (maths)', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Freight forwarder', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'Child psychotherapist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Hotel manager', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'Television camera operator', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Radiographer, therapeutic', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Town planner', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Machine Learning', 'Python', 'C++'], 'experience_title': 'Soil scientist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Q'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Chartered loss adjuster', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'experience_title': 'Forest/woodland manager', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['C++', 'Machine Learning', 'Java', 'Python'], 'experience_title': 'Scientist, research (maths)', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider T'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Architect', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Data Analysis', 'Python'], 'experience_title': 'Industrial buyer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider V'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Special educational needs teacher', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['SolidWorks', 'Structural Analysis', 'CAD', 'Thermodynamics'], 'experience_title': 'Editor, magazine features', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['CAD', 'Structural Analysis'], 'experience_title': 'Designer, industrial/product', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Event organiser', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'experience_title': 'Chiropodist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Machine Learning', 'Python', 'C++'], 'experience_title': 'Sport and exercise psychologist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider B'}
# {'required_skills': ['Data Analysis', 'C++', 'Python'], 'experience_title': 'Sales promotion account executive', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider C'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Site engineer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Data Analysis', 'C++'], 'experience_title': 'Osteopath', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider E'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Charity fundraiser', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Medical Imaging', 'Biomaterials'], 'experience_title': 'Chartered management accountant', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Biomaterials', 'Biomechanics'], 'experience_title': 'Surveyor, commercial/residential', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer'], 'experience_title': "Barrister's clerk", 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'Education officer, museum', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider J'}
# ...
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Armed forces training and education officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Python', 'Java'], 'experience_title': 'Special educational needs teacher', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider P'}
# {'required_skills': ['Data Analysis', 'Java'], 'experience_title': 'Water quality scientist', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider Q'}
# {'required_skills': ['Machine Learning', 'Java'], 'experience_title': 'Designer, multimedia', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider R'}
# {'required_skills': ['Medical Imaging', 'Biomechanics'], 'experience_title': 'Civil Service administrator', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Java', 'Machine Learning'], 'experience_title': 'Fitness centre manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider T'}
# {'required_skills': ['Power Systems', 'Microcontrollers'], 'experience_title': 'Sports administrator', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'experience_title': 'Retail banker', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Fisheries officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'Engineer, agricultural', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Professor Emeritus', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['SolidWorks', 'Structural Analysis', 'CAD', 'Thermodynamics'], 'experience_title': 'Toxicologist', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Psychiatrist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Pharmacist, community', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'experience_title': 'Corporate treasurer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Machine Learning', 'Data Analysis', 'Python', 'Java'], 'experience_title': 'Advertising copywriter', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider D'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Risk analyst', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Data Analysis', 'Machine Learning'], 'experience_title': 'Emergency planning/management officer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider F'}
# {'required_skills': ['Java', 'Machine Learning', 'Python'], 'experience_title': 'Television/film/video producer', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider G'}
# {'required_skills': ['Thermodynamics', 'SolidWorks'], 'experience_title': 'Manufacturing systems engineer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['C++', 'Python', 'Java'], 'experience_title': 'Hotel manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider I'}
# {'required_skills': ['CAD', 'Structural Analysis', 'Thermodynamics', 'SolidWorks'], 'experience_title': 'Horticulturist, commercial', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Designer, jewellery', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Data Analysis', 'Python'], 'experience_title': 'Accountant, chartered certified', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider L'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Engineer, biomedical', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Circuit Design', 'Microcontrollers', 'Power Systems'], 'experience_title': 'Garment/textile technologist', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'Magazine features editor', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Power Systems', 'Circuit Design'], 'experience_title': 'Immigration officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Runner, broadcasting/film/video', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Clinical psychologist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider R'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Tourism officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['SolidWorks', 'Structural Analysis'], 'experience_title': 'Scientist, audiological', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Editor, magazine features', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Machine Learning', 'Java', 'Python'], 'experience_title': 'Town planner', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider V'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Ambulance person', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Public relations account executive', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Thermodynamics', 'CAD'], 'experience_title': 'Estate agent', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Actuary', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'experience_title': 'Research scientist (medical)', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider A'}
# {'required_skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'experience_title': 'Company secretary', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider B'}
# {'required_skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'experience_title': 'Environmental manager', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Power Systems', 'Circuit Design'], 'experience_title': 'Housing manager/officer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Structural Analysis', 'SolidWorks', 'Thermodynamics'], 'experience_title': 'Communications engineer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Structural Analysis', 'Thermodynamics'], 'experience_title': 'Therapist, sports', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Biomechanics', 'Medical Imaging'], 'experience_title': 'Engineer, land', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'experience_title': 'Buyer, industrial', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Microcontrollers', 'Power Systems'], 'experience_title': 'Systems developer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'experience_title': 'Health and safety inspector', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Hospital doctor', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Circuit Design', 'Microcontrollers'], 'experience_title': 'Programme researcher, broadcasting/film/video', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider L'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Radio broadcast assistant', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider M'}
# {'required_skills': ['Thermodynamics', 'CAD'], 'experience_title': 'Retail banker', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider N'}
# {'required_skills': ['Thermodynamics', 'CAD', 'SolidWorks'], 'experience_title': 'Scientist, forensic', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider O'}
# {'required_skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'experience_title': 'Company secretary', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider P'}
# {'required_skills': ['Circuit Design', 'Microcontrollers'], 'experience_title': 'Production assistant, television', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider Q'}
# {'required_skills': ['Data Analysis', 'C++', 'Machine Learning', 'Python'], 'experience_title': 'Education administrator', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider R'}
# {'required_skills': ['SolidWorks', 'CAD', 'Thermodynamics'], 'experience_title': 'Dealer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider S'}
# {'required_skills': ['Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Theatre stage manager', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider T'}
# {'required_skills': ['Structural Analysis', 'SolidWorks'], 'experience_title': 'Optometrist', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider U'}
# {'required_skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'experience_title': 'Investment banker, operational', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider V'}
# {'required_skills': ['Thermodynamics', 'SolidWorks'], 'experience_title': 'Therapist, nutritional', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider W'}
# {'required_skills': ['Biomechanics', 'Biomaterials'], 'experience_title': 'Financial planner', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider X'}
# {'required_skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'experience_title': 'Press photographer', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Y'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Data scientist', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider Z'}
# {'required_skills': ['C++', 'Java', 'Data Analysis'], 'experience_title': 'Landscape architect', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider A'}
# {'required_skills': ['Data Analysis', 'Machine Learning'], 'experience_title': 'Fast food restaurant manager', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider B'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Web designer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider C'}
# {'required_skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'experience_title': 'Writer', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider D'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'Conservation officer, nature', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider E'}
# {'required_skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'experience_title': 'Physicist, medical', 'required_education': 'Bachelor of Science in Electrical Engineering', 'provider': 'Provider F'}
# {'required_skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'experience_title': 'Agricultural consultant', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider G'}
# {'required_skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'experience_title': 'Geneticist, molecular', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider H'}
# {'required_skills': ['Thermodynamics', 'CAD'], 'experience_title': 'Jewellery designer', 'required_education': 'Bachelor of Engineering in Mechanical Engineering', 'provider': 'Provider I'}
# {'required_skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'experience_title': 'Field seismologist', 'required_education': 'Bachelor of Science in Biomedical Engineering', 'provider': 'Provider J'}
# {'required_skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'experience_title': 'Homeopath', 'required_education': 'Bachelor of Science in Chemical Engineering', 'provider': 'Provider K'}
# {'required_skills': ['Machine Learning', 'Java', 'Python'], 'experience_title': 'Solicitor', 'required_education': 'Bachelor of Science in Computer Science', 'provider': 'Provider L'}

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
pip install faker
# Out:
# Requirement already satisfied: faker in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (22.7.0)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\acer\appdata\roaming\python\python311\site-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from faker import Faker
import random

fake = Faker()






# Sample data
sample_degrees = [
    "Bachelor of Science in Computer Science",
    "Bachelor of Engineering in Mechanical Engineering",
    "Bachelor of Science in Electrical Engineering",
    "Bachelor of Science in Chemical Engineering",
    "Bachelor of Science in Biomedical Engineering",
]

sample_skills = {
    "Computer Science": ["Python", "Java", "C++", "Machine Learning", "Data Analysis"],
    "Mechanical Engineering": ["CAD", "SolidWorks", "Thermodynamics", "Structural Analysis"],
    "Electrical Engineering": ["Circuit Design", "Microcontrollers", "Power Systems"],
    "Chemical Engineering": ["Chemical Process Design", "Chemical Kinetics", "Mass Transfer"],
    "Biomedical Engineering": ["Biomaterials", "Medical Imaging", "Biomechanics"],
}

# Function to generate a synthetic resume
def generate_resume():
    # Randomly select a degree
    degree = random.choice(sample_degrees)
    
    # Extract the field from the degree (splitting by 'in' and taking the last part)
    field = degree.split('in')[-1].strip()
    
    # Ensure the field is in sample_skills, or choose a random field if not found
    if field not in sample_skills:
        field = random.choice(list(sample_skills.keys()))
    
    # Randomly select skills for the resume, limiting the number of skills to 2-4
    num_skills = random.randint(2, min(4, len(sample_skills[field])))
    skills = random.sample(sample_skills[field], k=num_skills)

    # Generate a synthetic resume with skills, experience, and education
    return {
        "Skills": skills,
        "Experience": generate_experience(degree),
        "Education": degree
    }

# Generate a list of synthetic resumes
num_of_resumes = 1000  # You can change this to generate more resumes
synthetic_resumes = [generate_resume() for _ in range(num_of_resumes)]

# Display the generated resumes
for resume in synthetic_resumes:
    print(resume)
# Out:
# {'Skills': ['C++', 'Data Analysis'], 'Experience': [{'title': 'Biochemist, clinical', 'duration': '4 years'}, {'title': 'Clinical cytogeneticist', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Java', 'Python'], 'Experience': [{'title': 'Land/geomatics surveyor', 'duration': '3 years'}, {'title': 'Computer games developer', 'duration': '3 years'}, {'title': 'Engineer, site', 'duration': '5 years'}, {'title': 'Technical author', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Television/film/video producer', 'duration': '2 years'}, {'title': 'Buyer, industrial', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Adult guidance worker', 'duration': '3 years'}, {'title': 'Scientific laboratory technician', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Circuit Design', 'Power Systems'], 'Experience': [{'title': 'Cytogeneticist', 'duration': '4 years'}, {'title': 'Financial trader', 'duration': '4 years'}, {'title': 'Environmental health practitioner', 'duration': '5 years'}, {'title': 'Logistics and distribution manager', 'duration': '3 years'}, {'title': 'English as a second language teacher', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Dealer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Structural Analysis', 'CAD'], 'Experience': [{'title': 'Adult guidance worker', 'duration': '1 years'}, {'title': 'Engineer, manufacturing systems', 'duration': '3 years'}, {'title': 'Cytogeneticist', 'duration': '2 years'}, {'title': 'Sales executive', 'duration': '5 years'}, {'title': 'Advertising account executive', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'Experience': [{'title': 'Scientist, clinical (histocompatibility and immunogenetics)', 'duration': '3 years'}, {'title': 'Media buyer', 'duration': '4 years'}, {'title': 'Scientist, clinical (histocompatibility and immunogenetics)', 'duration': '5 years'}, {'title': 'Broadcast journalist', 'duration': '5 years'}, {'title': 'Podiatrist', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Clinical research associate', 'duration': '1 years'}, {'title': 'Broadcast engineer', 'duration': '4 years'}, {'title': 'Financial manager', 'duration': '2 years'}, {'title': 'Armed forces technical officer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Learning mentor', 'duration': '2 years'}, {'title': 'Designer, jewellery', 'duration': '3 years'}, {'title': 'Tourist information centre manager', 'duration': '3 years'}, {'title': 'Commercial/residential surveyor', 'duration': '4 years'}, {'title': 'Pension scheme manager', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Power Systems', 'Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Lobbyist', 'duration': '1 years'}, {'title': 'Visual merchandiser', 'duration': '5 years'}, {'title': 'Bonds trader', 'duration': '1 years'}, {'title': 'Scientist, research (medical)', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['CAD', 'Structural Analysis'], 'Experience': [{'title': 'Geoscientist', 'duration': '4 years'}, {'title': 'Warehouse manager', 'duration': '4 years'}, {'title': 'Cabin crew', 'duration': '5 years'}, {'title': 'Biomedical scientist', 'duration': '2 years'}, {'title': 'Building control surveyor', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Java', 'Data Analysis', 'Python'], 'Experience': [{'title': 'Librarian, academic', 'duration': '1 years'}, {'title': 'Health visitor', 'duration': '4 years'}, {'title': 'Clinical molecular geneticist', 'duration': '3 years'}, {'title': 'Therapist, art', 'duration': '5 years'}, {'title': 'Minerals surveyor', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Java', 'Machine Learning'], 'Experience': [{'title': 'Audiological scientist', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Python', 'Machine Learning', 'Data Analysis', 'C++'], 'Experience': [{'title': 'Chief of Staff', 'duration': '3 years'}, {'title': 'Product/process development scientist', 'duration': '4 years'}, {'title': 'Social researcher', 'duration': '5 years'}, {'title': 'Paramedic', 'duration': '2 years'}, {'title': 'Theme park manager', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['CAD', 'SolidWorks', 'Structural Analysis', 'Thermodynamics'], 'Experience': [{'title': "Politician's assistant", 'duration': '4 years'}, {'title': 'Market researcher', 'duration': '3 years'}, {'title': 'Aid worker', 'duration': '3 years'}, {'title': 'Haematologist', 'duration': '3 years'}, {'title': 'Arts administrator', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Java', 'C++', 'Machine Learning'], 'Experience': [{'title': 'Paediatric nurse', 'duration': '4 years'}, {'title': 'Psychologist, sport and exercise', 'duration': '5 years'}, {'title': 'Network engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Machine Learning', 'Python', 'C++', 'Data Analysis'], 'Experience': [{'title': 'Designer, jewellery', 'duration': '2 years'}, {'title': 'Psychotherapist, dance movement', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Machine Learning', 'Data Analysis', 'Python'], 'Experience': [{'title': 'Water engineer', 'duration': '1 years'}, {'title': 'Primary school teacher', 'duration': '1 years'}, {'title': "Barrister's clerk", 'duration': '5 years'}, {'title': 'Pathologist', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['SolidWorks', 'Thermodynamics'], 'Experience': [{'title': 'Transport planner', 'duration': '2 years'}, {'title': 'Human resources officer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'Experience': [{'title': 'Television camera operator', 'duration': '1 years'}, {'title': 'Field seismologist', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'Experience': [{'title': 'Energy engineer', 'duration': '3 years'}, {'title': 'Graphic designer', 'duration': '3 years'}, {'title': 'Training and development officer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Structural Analysis', 'CAD', 'SolidWorks'], 'Experience': [{'title': 'Accountant, chartered public finance', 'duration': '1 years'}, {'title': 'Ambulance person', 'duration': '3 years'}, {'title': 'Sales promotion account executive', 'duration': '4 years'}, {'title': 'Hydrographic surveyor', 'duration': '5 years'}, {'title': 'Warden/ranger', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Insurance claims handler', 'duration': '5 years'}, {'title': 'Forest/woodland manager', 'duration': '1 years'}, {'title': 'Optician, dispensing', 'duration': '3 years'}, {'title': 'Trading standards officer', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['C++', 'Java', 'Python', 'Data Analysis'], 'Experience': [{'title': 'Geneticist, molecular', 'duration': '4 years'}, {'title': 'Geophysical data processor', 'duration': '1 years'}, {'title': 'Merchant navy officer', 'duration': '3 years'}, {'title': 'Government social research officer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Veterinary surgeon', 'duration': '4 years'}, {'title': 'Sport and exercise psychologist', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Data Analysis', 'Java', 'Machine Learning', 'C++'], 'Experience': [{'title': 'Clinical embryologist', 'duration': '2 years'}, {'title': 'Location manager', 'duration': '2 years'}, {'title': 'Engineer, energy', 'duration': '5 years'}, {'title': 'Technical sales engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Machine Learning', 'Python', 'Java'], 'Experience': [{'title': 'Product designer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Scientific laboratory technician', 'duration': '1 years'}, {'title': 'Air traffic controller', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Chiropractor', 'duration': '1 years'}, {'title': 'Forest/woodland manager', 'duration': '4 years'}, {'title': 'Insurance claims handler', 'duration': '3 years'}, {'title': 'Designer, ceramics/pottery', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Systems developer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Chemical Process Design'], 'Experience': [{'title': 'Early years teacher', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Engineer, mining', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Accountant, chartered certified', 'duration': '5 years'}, {'title': 'Environmental manager', 'duration': '1 years'}, {'title': 'Sales executive', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomechanics'], 'Experience': [{'title': 'Therapist, art', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Oncologist', 'duration': '2 years'}, {'title': 'Manufacturing systems engineer', 'duration': '3 years'}, {'title': 'Equities trader', 'duration': '2 years'}, {'title': 'Physicist, medical', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['C++', 'Java', 'Machine Learning', 'Python'], 'Experience': [{'title': 'Freight forwarder', 'duration': '2 years'}, {'title': 'Early years teacher', 'duration': '5 years'}, {'title': 'Television production assistant', 'duration': '3 years'}, {'title': 'Operational investment banker', 'duration': '5 years'}, {'title': 'Administrator, education', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Biomechanics', 'Medical Imaging'], 'Experience': [{'title': 'Cartographer', 'duration': '5 years'}, {'title': 'Phytotherapist', 'duration': '2 years'}, {'title': 'Magazine journalist', 'duration': '2 years'}, {'title': 'Company secretary', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'Experience': [{'title': 'Aeronautical engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['C++', 'Machine Learning', 'Java'], 'Experience': [{'title': 'Music tutor', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Java', 'Machine Learning', 'Data Analysis'], 'Experience': [{'title': 'Administrator, arts', 'duration': '1 years'}, {'title': 'Human resources officer', 'duration': '3 years'}, {'title': 'Educational psychologist', 'duration': '1 years'}, {'title': 'Exhibition designer', 'duration': '1 years'}, {'title': 'Runner, broadcasting/film/video', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Python', 'Data Analysis', 'C++'], 'Experience': [{'title': 'Insurance broker', 'duration': '5 years'}, {'title': 'Technical sales engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Biomechanics', 'Medical Imaging'], 'Experience': [{'title': 'Scientist, physiological', 'duration': '5 years'}, {'title': 'Medical secretary', 'duration': '3 years'}, {'title': 'Telecommunications researcher', 'duration': '4 years'}, {'title': 'Chartered loss adjuster', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'Experience': [{'title': 'Catering manager', 'duration': '4 years'}, {'title': 'Publishing copy', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Circuit Design', 'Power Systems'], 'Experience': [{'title': 'Engineer, automotive', 'duration': '5 years'}, {'title': 'Chiropodist', 'duration': '4 years'}, {'title': 'Clothing/textile technologist', 'duration': '4 years'}, {'title': "Barrister's clerk", 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Python', 'Machine Learning'], 'Experience': [{'title': 'Museum/gallery conservator', 'duration': '3 years'}, {'title': 'Animal nutritionist', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Biomechanics', 'Biomaterials'], 'Experience': [{'title': 'Landscape architect', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Arboriculturist', 'duration': '5 years'}, {'title': 'Health promotion specialist', 'duration': '5 years'}, {'title': 'Lighting technician, broadcasting/film/video', 'duration': '2 years'}, {'title': 'Museum/gallery conservator', 'duration': '1 years'}, {'title': 'Scientist, research (maths)', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Machine Learning', 'Python'], 'Experience': [{'title': 'Arboriculturist', 'duration': '1 years'}, {'title': 'Solicitor', 'duration': '2 years'}, {'title': 'Public relations account executive', 'duration': '3 years'}, {'title': 'Curator', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Network engineer', 'duration': '3 years'}, {'title': 'Systems developer', 'duration': '4 years'}, {'title': 'Chief Financial Officer', 'duration': '3 years'}, {'title': 'Chartered accountant', 'duration': '3 years'}, {'title': 'Lawyer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Trade mark attorney', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Machine Learning', 'C++', 'Data Analysis', 'Java'], 'Experience': [{'title': 'Multimedia specialist', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Theatre manager', 'duration': '2 years'}, {'title': 'Surveyor, building control', 'duration': '1 years'}, {'title': 'Radiographer, therapeutic', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Engineer, maintenance', 'duration': '4 years'}, {'title': 'Legal executive', 'duration': '4 years'}, {'title': 'Designer, interior/spatial', 'duration': '5 years'}, {'title': 'Clinical embryologist', 'duration': '2 years'}, {'title': 'Outdoor activities/education manager', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Research scientist (maths)', 'duration': '3 years'}, {'title': 'Video editor', 'duration': '5 years'}, {'title': 'Television production assistant', 'duration': '5 years'}, {'title': "Barrister's clerk", 'duration': '2 years'}, {'title': 'Engineer, drilling', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Machine Learning', 'Python', 'Java'], 'Experience': [{'title': 'Exhibitions officer, museum/gallery', 'duration': '1 years'}, {'title': 'Learning disability nurse', 'duration': '5 years'}, {'title': 'Careers information officer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Machine Learning', 'Java'], 'Experience': [{'title': 'Multimedia specialist', 'duration': '1 years'}, {'title': 'Surveyor, mining', 'duration': '4 years'}, {'title': 'Information officer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'Experience': [{'title': 'Risk manager', 'duration': '3 years'}, {'title': 'Geophysicist/field seismologist', 'duration': '1 years'}, {'title': 'Amenity horticulturist', 'duration': '3 years'}, {'title': 'Applications developer', 'duration': '1 years'}, {'title': 'Hydrologist', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Circuit Design', 'Microcontrollers', 'Power Systems'], 'Experience': [{'title': 'Archaeologist', 'duration': '5 years'}, {'title': 'Designer, graphic', 'duration': '2 years'}, {'title': 'Meteorologist', 'duration': '5 years'}, {'title': 'Theatre manager', 'duration': '4 years'}, {'title': 'Animal nutritionist', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['C++', 'Data Analysis'], 'Experience': [{'title': 'Librarian, public', 'duration': '1 years'}, {'title': 'Database administrator', 'duration': '2 years'}, {'title': 'Surveyor, hydrographic', 'duration': '3 years'}, {'title': 'Architectural technologist', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Data Analysis', 'Python', 'Machine Learning'], 'Experience': [{'title': 'Engineer, maintenance (IT)', 'duration': '3 years'}, {'title': 'Radiation protection practitioner', 'duration': '2 years'}, {'title': 'Civil Service administrator', 'duration': '5 years'}, {'title': 'Historic buildings inspector/conservation officer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Technical sales engineer', 'duration': '4 years'}, {'title': 'Sports administrator', 'duration': '5 years'}, {'title': 'Counselling psychologist', 'duration': '5 years'}, {'title': 'Surgeon', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['SolidWorks', 'CAD', 'Thermodynamics'], 'Experience': [{'title': 'Podiatrist', 'duration': '2 years'}, {'title': 'Scientist, research (physical sciences)', 'duration': '5 years'}, {'title': 'Accountant, chartered certified', 'duration': '2 years'}, {'title': 'Manufacturing systems engineer', 'duration': '3 years'}, {'title': 'Accountant, chartered', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Machine Learning', 'C++'], 'Experience': [{'title': 'Camera operator', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Operational researcher', 'duration': '4 years'}, {'title': 'Multimedia specialist', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Structural Analysis', 'Thermodynamics', 'CAD', 'SolidWorks'], 'Experience': [{'title': 'Comptroller', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Homeopath', 'duration': '5 years'}, {'title': 'Warehouse manager', 'duration': '5 years'}, {'title': 'Town planner', 'duration': '1 years'}, {'title': "Barrister's clerk", 'duration': '5 years'}, {'title': 'Associate Professor', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Java', 'Machine Learning'], 'Experience': [{'title': 'Regulatory affairs officer', 'duration': '2 years'}, {'title': 'Civil Service fast streamer', 'duration': '2 years'}, {'title': 'Journalist, broadcasting', 'duration': '2 years'}, {'title': 'Ergonomist', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Nurse, learning disability', 'duration': '3 years'}, {'title': 'Psychologist, prison and probation services', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Machine Learning', 'Data Analysis', 'Java'], 'Experience': [{'title': 'Landscape architect', 'duration': '3 years'}, {'title': 'Nature conservation officer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Power Systems', 'Microcontrollers'], 'Experience': [{'title': 'Sports development officer', 'duration': '1 years'}, {'title': 'Environmental education officer', 'duration': '5 years'}, {'title': 'Environmental health practitioner', 'duration': '5 years'}, {'title': 'Mental health nurse', 'duration': '2 years'}, {'title': 'Engineer, site', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Machine Learning', 'Java'], 'Experience': [{'title': 'Engineer, site', 'duration': '4 years'}, {'title': 'Site engineer', 'duration': '5 years'}, {'title': 'Corporate investment banker', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Java', 'Python'], 'Experience': [{'title': 'Insurance claims handler', 'duration': '4 years'}, {'title': 'Diplomatic Services operational officer', 'duration': '5 years'}, {'title': 'Legal executive', 'duration': '1 years'}, {'title': 'Radio broadcast assistant', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Management consultant', 'duration': '5 years'}, {'title': 'Solicitor', 'duration': '5 years'}, {'title': 'Press sub', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Biomechanics', 'Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Solicitor, Scotland', 'duration': '2 years'}, {'title': 'Development worker, community', 'duration': '1 years'}, {'title': 'Animal nutritionist', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Machine Learning', 'Python', 'Java'], 'Experience': [{'title': 'Designer, television/film set', 'duration': '1 years'}, {'title': 'Medical sales representative', 'duration': '2 years'}, {'title': 'Equities trader', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Sound technician, broadcasting/film/video', 'duration': '3 years'}, {'title': 'Chief Strategy Officer', 'duration': '2 years'}, {'title': 'Barista', 'duration': '4 years'}, {'title': 'Surveyor, land/geomatics', 'duration': '5 years'}, {'title': 'Building surveyor', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Machine Learning', 'Data Analysis'], 'Experience': [{'title': 'Learning disability nurse', 'duration': '1 years'}, {'title': 'Web designer', 'duration': '1 years'}, {'title': 'Mental health nurse', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Medical Imaging', 'Biomechanics'], 'Experience': [{'title': 'Licensed conveyancer', 'duration': '4 years'}, {'title': 'Fine artist', 'duration': '2 years'}, {'title': 'Building control surveyor', 'duration': '4 years'}, {'title': 'Financial planner', 'duration': '3 years'}, {'title': 'Production designer, theatre/television/film', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Data scientist', 'duration': '2 years'}, {'title': 'Printmaker', 'duration': '4 years'}, {'title': 'Web designer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['CAD', 'Structural Analysis'], 'Experience': [{'title': 'Energy engineer', 'duration': '1 years'}, {'title': 'Network engineer', 'duration': '5 years'}, {'title': 'Chartered certified accountant', 'duration': '5 years'}, {'title': 'Chartered loss adjuster', 'duration': '2 years'}, {'title': 'Scientist, research (physical sciences)', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Audiological scientist', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['C++', 'Data Analysis'], 'Experience': [{'title': 'Chartered accountant', 'duration': '3 years'}, {'title': 'Industrial/product designer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['C++', 'Python'], 'Experience': [{'title': 'Radiation protection practitioner', 'duration': '3 years'}, {'title': 'Social research officer, government', 'duration': '2 years'}, {'title': 'Operational investment banker', 'duration': '4 years'}, {'title': 'Occupational hygienist', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['C++', 'Machine Learning', 'Python', 'Data Analysis'], 'Experience': [{'title': 'Educational psychologist', 'duration': '3 years'}, {'title': 'Trade union research officer', 'duration': '5 years'}, {'title': 'Advertising art director', 'duration': '5 years'}, {'title': 'IT technical support officer', 'duration': '3 years'}, {'title': 'Conference centre manager', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Machine Learning', 'Java', 'C++', 'Python'], 'Experience': [{'title': 'Broadcast presenter', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Circuit Design', 'Power Systems', 'Microcontrollers'], 'Experience': [{'title': 'Ship broker', 'duration': '4 years'}, {'title': 'Commercial/residential surveyor', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Java', 'Machine Learning', 'Data Analysis', 'Python'], 'Experience': [{'title': 'Quality manager', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Thermodynamics', 'Structural Analysis'], 'Experience': [{'title': 'Personal assistant', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Machine Learning', 'C++', 'Python'], 'Experience': [{'title': 'Maintenance engineer', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Data Analysis', 'Python', 'C++'], 'Experience': [{'title': 'Chiropractor', 'duration': '2 years'}, {'title': 'Legal secretary', 'duration': '2 years'}, {'title': 'Biochemist, clinical', 'duration': '4 years'}, {'title': 'Engineer, aeronautical', 'duration': '3 years'}, {'title': 'Multimedia programmer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['CAD', 'Thermodynamics', 'SolidWorks', 'Structural Analysis'], 'Experience': [{'title': 'Musician', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Data Analysis', 'Java'], 'Experience': [{'title': 'Commercial horticulturist', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Machine Learning', 'Java', 'Data Analysis', 'Python'], 'Experience': [{'title': 'Garment/textile technologist', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers'], 'Experience': [{'title': 'Advice worker', 'duration': '2 years'}, {'title': 'Hydrologist', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Biomechanics', 'Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Sports therapist', 'duration': '1 years'}, {'title': 'Engineer, petroleum', 'duration': '2 years'}, {'title': 'Loss adjuster, chartered', 'duration': '4 years'}, {'title': 'Warehouse manager', 'duration': '1 years'}, {'title': 'Social research officer, government', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Scientist, research (physical sciences)', 'duration': '5 years'}, {'title': 'Development worker, international aid', 'duration': '3 years'}, {'title': 'Contractor', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Python', 'Java', 'Data Analysis', 'Machine Learning'], 'Experience': [{'title': 'Advertising account planner', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Machine Learning', 'Java', 'Data Analysis'], 'Experience': [{'title': 'Graphic designer', 'duration': '5 years'}, {'title': 'Psychotherapist, dance movement', 'duration': '4 years'}, {'title': 'Psychologist, occupational', 'duration': '2 years'}, {'title': 'Financial trader', 'duration': '3 years'}, {'title': 'Gaffer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Java', 'Python'], 'Experience': [{'title': 'Risk manager', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['C++', 'Python'], 'Experience': [{'title': 'Therapist, horticultural', 'duration': '3 years'}, {'title': 'Public affairs consultant', 'duration': '4 years'}, {'title': 'Engineer, site', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['C++', 'Machine Learning', 'Python'], 'Experience': [{'title': 'Broadcast journalist', 'duration': '5 years'}, {'title': 'Environmental education officer', 'duration': '4 years'}, {'title': 'Visual merchandiser', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Data Analysis', 'Machine Learning'], 'Experience': [{'title': 'Therapist, drama', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Thermodynamics', 'CAD', 'Structural Analysis'], 'Experience': [{'title': 'Materials engineer', 'duration': '1 years'}, {'title': 'Corporate treasurer', 'duration': '3 years'}, {'title': 'Tourism officer', 'duration': '1 years'}, {'title': 'Local government officer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Mass Transfer'], 'Experience': [{'title': 'Scientist, physiological', 'duration': '1 years'}, {'title': 'Theatre manager', 'duration': '3 years'}, {'title': 'Publishing rights manager', 'duration': '2 years'}, {'title': 'Radiographer, therapeutic', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['C++', 'Data Analysis', 'Machine Learning'], 'Experience': [{'title': 'Scientist, clinical (histocompatibility and immunogenetics)', 'duration': '2 years'}, {'title': 'Furniture designer', 'duration': '5 years'}, {'title': 'Barrister', 'duration': '2 years'}, {'title': 'Conservation officer, historic buildings', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Cytogeneticist', 'duration': '2 years'}, {'title': 'Museum/gallery curator', 'duration': '3 years'}, {'title': 'Occupational hygienist', 'duration': '5 years'}, {'title': 'Aeronautical engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Biomechanics', 'Biomaterials'], 'Experience': [{'title': 'Insurance claims handler', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'Experience': [{'title': 'Prison officer', 'duration': '1 years'}, {'title': 'Radio producer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Physiotherapist', 'duration': '3 years'}, {'title': 'Chief Strategy Officer', 'duration': '5 years'}, {'title': 'Barista', 'duration': '1 years'}, {'title': 'Therapist, nutritional', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Biomechanics', 'Medical Imaging'], 'Experience': [{'title': 'Sports therapist', 'duration': '5 years'}, {'title': 'Volunteer coordinator', 'duration': '5 years'}, {'title': 'Surveyor, minerals', 'duration': '2 years'}, {'title': 'Administrator, education', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Java', 'Python', 'C++', 'Data Analysis'], 'Experience': [{'title': 'Development worker, international aid', 'duration': '2 years'}, {'title': 'Conference centre manager', 'duration': '4 years'}, {'title': 'Embryologist, clinical', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['SolidWorks', 'Thermodynamics'], 'Experience': [{'title': 'Toxicologist', 'duration': '1 years'}, {'title': 'Scientist, marine', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Mass Transfer'], 'Experience': [{'title': 'Primary school teacher', 'duration': '2 years'}, {'title': 'Engineer, production', 'duration': '3 years'}, {'title': 'Sport and exercise psychologist', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers'], 'Experience': [{'title': 'Public house manager', 'duration': '2 years'}, {'title': 'Surveyor, rural practice', 'duration': '2 years'}, {'title': 'Water engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Circuit Design', 'Power Systems'], 'Experience': [{'title': 'Dispensing optician', 'duration': '4 years'}, {'title': 'Special effects artist', 'duration': '2 years'}, {'title': 'Clinical cytogeneticist', 'duration': '5 years'}, {'title': 'Careers information officer', 'duration': '4 years'}, {'title': 'Restaurant manager, fast food', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'Experience': [{'title': 'Event organiser', 'duration': '4 years'}, {'title': 'Printmaker', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['CAD', 'Structural Analysis', 'SolidWorks'], 'Experience': [{'title': 'Engineer, land', 'duration': '5 years'}, {'title': 'Commercial horticulturist', 'duration': '1 years'}, {'title': 'Toxicologist', 'duration': '1 years'}, {'title': 'Financial adviser', 'duration': '3 years'}, {'title': 'Trading standards officer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['C++', 'Python'], 'Experience': [{'title': 'Medical secretary', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Structural Analysis', 'Thermodynamics', 'CAD'], 'Experience': [{'title': 'Clinical embryologist', 'duration': '3 years'}, {'title': 'Air cabin crew', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['C++', 'Java', 'Data Analysis'], 'Experience': [{'title': "Barrister's clerk", 'duration': '1 years'}, {'title': 'IT trainer', 'duration': '4 years'}, {'title': 'Education officer, community', 'duration': '1 years'}, {'title': 'Horticulturist, amenity', 'duration': '1 years'}, {'title': 'Surveyor, quantity', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Data Analysis', 'Python', 'Machine Learning', 'Java'], 'Experience': [{'title': 'Solicitor', 'duration': '2 years'}, {'title': 'Broadcast engineer', 'duration': '2 years'}, {'title': 'Broadcast engineer', 'duration': '3 years'}, {'title': 'Media planner', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Biomaterials', 'Medical Imaging', 'Biomechanics'], 'Experience': [{'title': 'Physicist, medical', 'duration': '5 years'}, {'title': 'Dramatherapist', 'duration': '5 years'}, {'title': 'Merchant navy officer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics', 'Medical Imaging'], 'Experience': [{'title': 'Lecturer, higher education', 'duration': '1 years'}, {'title': 'Copywriter, advertising', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Python', 'Java', 'Machine Learning', 'C++'], 'Experience': [{'title': 'Further education lecturer', 'duration': '4 years'}, {'title': 'Land', 'duration': '1 years'}, {'title': 'Clinical scientist, histocompatibility and immunogenetics', 'duration': '4 years'}, {'title': 'Physicist, medical', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Kinetics', 'Chemical Process Design'], 'Experience': [{'title': 'Fisheries officer', 'duration': '4 years'}, {'title': 'Exhibitions officer, museum/gallery', 'duration': '5 years'}, {'title': 'Diagnostic radiographer', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['CAD', 'Thermodynamics', 'SolidWorks'], 'Experience': [{'title': 'Theme park manager', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Administrator', 'duration': '2 years'}, {'title': 'Public house manager', 'duration': '4 years'}, {'title': 'Professor Emeritus', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Python', 'Java'], 'Experience': [{'title': 'Accountant, chartered certified', 'duration': '5 years'}, {'title': 'Programme researcher, broadcasting/film/video', 'duration': '1 years'}, {'title': 'Community development worker', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Medical Imaging', 'Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Scientist, physiological', 'duration': '2 years'}, {'title': 'Economist', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'Experience': [{'title': 'Armed forces operational officer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Machine Learning', 'Data Analysis'], 'Experience': [{'title': 'Production designer, theatre/television/film', 'duration': '3 years'}, {'title': 'Estate agent', 'duration': '3 years'}, {'title': 'Chiropractor', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Data Analysis', 'C++'], 'Experience': [{'title': 'Magazine features editor', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Biomechanics', 'Medical Imaging'], 'Experience': [{'title': 'Occupational hygienist', 'duration': '1 years'}, {'title': 'Financial planner', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['CAD', 'Thermodynamics', 'Structural Analysis'], 'Experience': [{'title': 'Technical brewer', 'duration': '5 years'}, {'title': 'Education administrator', 'duration': '2 years'}, {'title': 'Information officer', 'duration': '2 years'}, {'title': 'Pathologist', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Industrial buyer', 'duration': '5 years'}, {'title': 'Insurance broker', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Ophthalmologist', 'duration': '5 years'}, {'title': 'Psychologist, occupational', 'duration': '2 years'}, {'title': 'Chartered certified accountant', 'duration': '4 years'}, {'title': 'Building control surveyor', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Java', 'C++', 'Python', 'Machine Learning'], 'Experience': [{'title': 'Ship broker', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Kinetics', 'Mass Transfer'], 'Experience': [{'title': 'Advertising account executive', 'duration': '4 years'}, {'title': 'Systems developer', 'duration': '1 years'}, {'title': 'Claims inspector/assessor', 'duration': '1 years'}, {'title': 'Facilities manager', 'duration': '2 years'}, {'title': 'Field trials officer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['SolidWorks', 'Structural Analysis', 'Thermodynamics'], 'Experience': [{'title': 'Risk manager', 'duration': '2 years'}, {'title': 'Cartographer', 'duration': '2 years'}, {'title': 'Naval architect', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Learning mentor', 'duration': '3 years'}, {'title': 'Art gallery manager', 'duration': '1 years'}, {'title': 'Animal technologist', 'duration': '2 years'}, {'title': 'Conservator, furniture', 'duration': '4 years'}, {'title': 'Scientist, research (medical)', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Machine Learning', 'Data Analysis', 'C++'], 'Experience': [{'title': 'Operational researcher', 'duration': '5 years'}, {'title': 'Commercial/residential surveyor', 'duration': '5 years'}, {'title': 'Physiological scientist', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Machine Learning', 'Java'], 'Experience': [{'title': 'Editor, magazine features', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'Experience': [{'title': 'Biomedical engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['C++', 'Java'], 'Experience': [{'title': 'Accountant, chartered', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Horticultural consultant', 'duration': '5 years'}, {'title': 'Counsellor', 'duration': '4 years'}, {'title': 'Television production assistant', 'duration': '3 years'}, {'title': 'Aid worker', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Mass Transfer', 'Chemical Process Design'], 'Experience': [{'title': 'Catering manager', 'duration': '2 years'}, {'title': 'Archaeologist', 'duration': '3 years'}, {'title': 'Multimedia programmer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer'], 'Experience': [{'title': 'Surgeon', 'duration': '1 years'}, {'title': 'Market researcher', 'duration': '4 years'}, {'title': 'Marine scientist', 'duration': '2 years'}, {'title': 'Psychologist, clinical', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Museum/gallery curator', 'duration': '1 years'}, {'title': 'Therapeutic radiographer', 'duration': '3 years'}, {'title': 'Chief Operating Officer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Python', 'Data Analysis', 'Java', 'Machine Learning'], 'Experience': [{'title': 'Horticulturist, commercial', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Python', 'Data Analysis'], 'Experience': [{'title': 'Ranger/warden', 'duration': '1 years'}, {'title': 'Radio broadcast assistant', 'duration': '4 years'}, {'title': 'Teacher, primary school', 'duration': '5 years'}, {'title': 'Exhibition designer', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Data Analysis', 'Java', 'C++', 'Python'], 'Experience': [{'title': 'Horticultural therapist', 'duration': '4 years'}, {'title': 'Pharmacist, hospital', 'duration': '1 years'}, {'title': 'Computer games developer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Structural Analysis', 'SolidWorks', 'CAD'], 'Experience': [{'title': 'Data processing manager', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Machine Learning', 'Python', 'Data Analysis'], 'Experience': [{'title': 'Stage manager', 'duration': '4 years'}, {'title': 'Accountant, chartered certified', 'duration': '1 years'}, {'title': 'Therapist, nutritional', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# ...
# {'Skills': ['Biomechanics', 'Biomaterials'], 'Experience': [{'title': 'Armed forces operational officer', 'duration': '4 years'}, {'title': 'Quality manager', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomechanics', 'Biomaterials'], 'Experience': [{'title': 'Administrator', 'duration': '3 years'}, {'title': 'Investment analyst', 'duration': '5 years'}, {'title': 'Engineer, drilling', 'duration': '2 years'}, {'title': 'Social researcher', 'duration': '2 years'}, {'title': 'Private music teacher', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Process Design'], 'Experience': [{'title': 'Cytogeneticist', 'duration': '1 years'}, {'title': 'Illustrator', 'duration': '1 years'}, {'title': 'Systems analyst', 'duration': '3 years'}, {'title': 'Administrator, sports', 'duration': '5 years'}, {'title': 'Mining engineer', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Data Analysis', 'C++', 'Java', 'Python'], 'Experience': [{'title': 'Patent examiner', 'duration': '5 years'}, {'title': 'Careers adviser', 'duration': '4 years'}, {'title': 'Designer, textile', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Data Analysis', 'C++', 'Python', 'Machine Learning'], 'Experience': [{'title': 'Editorial assistant', 'duration': '3 years'}, {'title': 'Geologist, wellsite', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Production assistant, television', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Java', 'Machine Learning'], 'Experience': [{'title': 'Scientist, physiological', 'duration': '1 years'}, {'title': 'Pensions consultant', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Chemical Process Design', 'Chemical Kinetics', 'Mass Transfer'], 'Experience': [{'title': 'Clinical embryologist', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['C++', 'Python', 'Machine Learning'], 'Experience': [{'title': 'Textile designer', 'duration': '4 years'}, {'title': 'Clinical biochemist', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Power Systems', 'Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Phytotherapist', 'duration': '1 years'}, {'title': 'Accommodation manager', 'duration': '3 years'}, {'title': 'Retail banker', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'Experience': [{'title': 'Herpetologist', 'duration': '2 years'}, {'title': 'Operational researcher', 'duration': '3 years'}, {'title': 'Librarian, academic', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Python', 'Machine Learning'], 'Experience': [{'title': 'Producer, radio', 'duration': '1 years'}, {'title': 'Editor, commissioning', 'duration': '1 years'}, {'title': 'Journalist, broadcasting', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Designer, interior/spatial', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Python', 'Java', 'C++'], 'Experience': [{'title': 'Engineering geologist', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['CAD', 'Thermodynamics', 'SolidWorks'], 'Experience': [{'title': 'Building services engineer', 'duration': '5 years'}, {'title': 'Production engineer', 'duration': '1 years'}, {'title': 'Human resources officer', 'duration': '2 years'}, {'title': 'Race relations officer', 'duration': '4 years'}, {'title': 'Designer, industrial/product', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['SolidWorks', 'CAD'], 'Experience': [{'title': 'Engineer, maintenance', 'duration': '4 years'}, {'title': 'Geologist, engineering', 'duration': '3 years'}, {'title': 'Ergonomist', 'duration': '1 years'}, {'title': 'Clinical research associate', 'duration': '2 years'}, {'title': 'Designer, textile', 'duration': '4 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Exhibitions officer, museum/gallery', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Kinetics', 'Chemical Process Design'], 'Experience': [{'title': 'Engineer, communications', 'duration': '3 years'}, {'title': 'Engineer, electrical', 'duration': '2 years'}, {'title': 'Government social research officer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['CAD', 'Structural Analysis'], 'Experience': [{'title': 'Further education lecturer', 'duration': '4 years'}, {'title': 'Teacher, early years/pre', 'duration': '3 years'}, {'title': 'Insurance account manager', 'duration': '1 years'}, {'title': 'Insurance account manager', 'duration': '3 years'}, {'title': 'Theatre stage manager', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Process Design', 'Chemical Kinetics'], 'Experience': [{'title': 'Building surveyor', 'duration': '4 years'}, {'title': 'Freight forwarder', 'duration': '2 years'}, {'title': 'Therapeutic radiographer', 'duration': '1 years'}, {'title': 'Control and instrumentation engineer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Machine Learning', 'Python'], 'Experience': [{'title': 'Osteopath', 'duration': '5 years'}, {'title': 'Financial trader', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Machine Learning', 'Java', 'Python'], 'Experience': [{'title': 'Lobbyist', 'duration': '4 years'}, {'title': 'Further education lecturer', 'duration': '1 years'}, {'title': 'Recruitment consultant', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Professor Emeritus', 'duration': '1 years'}, {'title': 'Police officer', 'duration': '3 years'}, {'title': 'Engineer, chemical', 'duration': '2 years'}, {'title': 'Soil scientist', 'duration': '3 years'}, {'title': 'Chartered certified accountant', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Thermodynamics', 'SolidWorks'], 'Experience': [{'title': 'Dentist', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomechanics'], 'Experience': [{'title': 'Therapeutic radiographer', 'duration': '1 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['C++', 'Data Analysis', 'Python', 'Machine Learning'], 'Experience': [{'title': 'Youth worker', 'duration': '3 years'}, {'title': 'Planning and development surveyor', 'duration': '1 years'}, {'title': 'Restaurant manager, fast food', 'duration': '1 years'}, {'title': 'Chartered certified accountant', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['C++', 'Python'], 'Experience': [{'title': 'Designer, industrial/product', 'duration': '1 years'}, {'title': 'Dispensing optician', 'duration': '2 years'}, {'title': 'Ecologist', 'duration': '2 years'}, {'title': 'Television camera operator', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Data Analysis', 'Java', 'Machine Learning'], 'Experience': [{'title': 'Restaurant manager', 'duration': '2 years'}, {'title': 'Civil Service fast streamer', 'duration': '5 years'}, {'title': 'Engineer, civil (contracting)', 'duration': '2 years'}, {'title': 'Scientific laboratory technician', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Animal nutritionist', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Designer, fashion/clothing', 'duration': '5 years'}, {'title': 'Curator', 'duration': '4 years'}, {'title': 'Camera operator', 'duration': '5 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Microcontrollers', 'Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Architect', 'duration': '5 years'}, {'title': 'Estate manager/land agent', 'duration': '3 years'}, {'title': 'Field seismologist', 'duration': '1 years'}, {'title': 'Ophthalmologist', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Chemical Process Design', 'Mass Transfer', 'Chemical Kinetics'], 'Experience': [{'title': 'Television production assistant', 'duration': '2 years'}, {'title': 'TEFL teacher', 'duration': '4 years'}, {'title': 'Immigration officer', 'duration': '2 years'}, {'title': 'Health service manager', 'duration': '2 years'}, {'title': 'Science writer', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Machine Learning', 'C++', 'Data Analysis'], 'Experience': [{'title': 'Community arts worker', 'duration': '2 years'}, {'title': 'Special educational needs teacher', 'duration': '5 years'}, {'title': 'Music tutor', 'duration': '1 years'}, {'title': 'Toxicologist', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Biomaterials', 'Biomechanics'], 'Experience': [{'title': 'Field trials officer', 'duration': '3 years'}, {'title': 'Psychologist, counselling', 'duration': '3 years'}, {'title': 'Engineer, communications', 'duration': '3 years'}, {'title': 'Landscape architect', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['SolidWorks', 'Thermodynamics'], 'Experience': [{'title': 'Counselling psychologist', 'duration': '5 years'}, {'title': 'Field seismologist', 'duration': '5 years'}, {'title': 'Engineer, water', 'duration': '2 years'}, {'title': 'Chartered legal executive (England and Wales)', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Circuit Design', 'Microcontrollers'], 'Experience': [{'title': 'Neurosurgeon', 'duration': '2 years'}, {'title': 'Energy engineer', 'duration': '2 years'}, {'title': 'Counselling psychologist', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Public affairs consultant', 'duration': '2 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Power Systems', 'Circuit Design'], 'Experience': [{'title': 'Public house manager', 'duration': '3 years'}, {'title': 'English as a foreign language teacher', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['SolidWorks', 'Thermodynamics', 'CAD', 'Structural Analysis'], 'Experience': [{'title': 'Hospital doctor', 'duration': '5 years'}, {'title': 'Tourist information centre manager', 'duration': '5 years'}, {'title': 'Occupational hygienist', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design'], 'Experience': [{'title': 'Public librarian', 'duration': '1 years'}, {'title': 'Scientist, water quality', 'duration': '5 years'}, {'title': 'Soil scientist', 'duration': '5 years'}, {'title': 'Surveyor, building control', 'duration': '4 years'}, {'title': 'Automotive engineer', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Microcontrollers', 'Circuit Design', 'Power Systems'], 'Experience': [{'title': 'Programmer, multimedia', 'duration': '1 years'}, {'title': 'Acupuncturist', 'duration': '4 years'}, {'title': 'Psychotherapist', 'duration': '2 years'}, {'title': 'Psychologist, prison and probation services', 'duration': '1 years'}, {'title': 'Patent examiner', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Java', 'Python', 'C++'], 'Experience': [{'title': 'Archivist', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Machine Learning', 'Java', 'Data Analysis'], 'Experience': [{'title': 'Social researcher', 'duration': '5 years'}, {'title': 'Curator', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Computer Science'}
# {'Skills': ['Structural Analysis', 'CAD', 'Thermodynamics'], 'Experience': [{'title': 'Cabin crew', 'duration': '5 years'}, {'title': 'Customer service manager', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Biomaterials', 'Medical Imaging'], 'Experience': [{'title': 'Careers adviser', 'duration': '4 years'}, {'title': 'Engineer, maintenance', 'duration': '3 years'}, {'title': 'Television camera operator', 'duration': '3 years'}, {'title': 'Editor, film/video', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'Experience': [{'title': 'Hotel manager', 'duration': '5 years'}, {'title': 'Music tutor', 'duration': '3 years'}, {'title': 'Engineer, drilling', 'duration': '5 years'}, {'title': 'Producer, television/film/video', 'duration': '2 years'}, {'title': 'Chemical engineer', 'duration': '4 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Medical Imaging', 'Biomaterials'], 'Experience': [{'title': 'Mechanical engineer', 'duration': '3 years'}, {'title': 'Engineer, petroleum', 'duration': '1 years'}, {'title': 'Surveyor, quantity', 'duration': '5 years'}], 'Education': 'Bachelor of Science in Chemical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'Experience': [{'title': 'Lecturer, further education', 'duration': '4 years'}, {'title': 'Mining engineer', 'duration': '4 years'}, {'title': 'Engineering geologist', 'duration': '3 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}
# {'Skills': ['Mass Transfer', 'Chemical Kinetics', 'Chemical Process Design'], 'Experience': [{'title': 'Production engineer', 'duration': '5 years'}, {'title': 'Leisure centre manager', 'duration': '4 years'}, {'title': 'Administrator, education', 'duration': '2 years'}], 'Education': 'Bachelor of Science in Biomedical Engineering'}
# {'Skills': ['Python', 'Java'], 'Experience': [{'title': 'Database administrator', 'duration': '4 years'}, {'title': 'Programmer, systems', 'duration': '1 years'}, {'title': 'Special effects artist', 'duration': '2 years'}, {'title': 'Technical author', 'duration': '5 years'}, {'title': 'Educational psychologist', 'duration': '3 years'}], 'Education': 'Bachelor of Engineering in Mechanical Engineering'}
# {'Skills': ['Biomechanics', 'Medical Imaging'], 'Experience': [{'title': 'Museum/gallery curator', 'duration': '1 years'}], 'Education': 'Bachelor of Science in Electrical Engineering'}

# %%
def extract_keywords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    keywords = [word for word in word_tokens if word.isalpha() and word not in stop_words]
    return keywords


def extract_keywords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    keywords = [word for word in word_tokens if word.isalpha() and word not in stop_words]
    return keywords


for job in jobs_data:
    job['keywords'] = extract_keywords(' '.join(job['required_skills']) + ' ' + job['experience_title'] + ' ' + job['required_education'])

for resume in synthetic_resumes:
    resume['keywords'] = extract_keywords(' '.join(resume['Skills']) + ' ' + ' '.join([exp['title'] for exp in resume['Experience']]) + ' ' + resume['Education'])

    def match_score(job_keywords, resume_keywords):
     return len(set(job_keywords) & set(resume_keywords))

matches = []
for resume in synthetic_resumes:
    for job in jobs_data:
        score = match_score(job['keywords'], resume['keywords'])
        matches.append((score, job, resume))

# Sort matches based on score
matches.sort(reverse=True, key=lambda x: x[0])


for score, job, resume in matches[:500]:  # Display top 10 matches
    print(f"Match Score: {score}\nJob: {job['experience_title']}\nResume: {resume['Experience'][0]['title']}\n")
# Out:
# Match Score: 14
# Job: Armed forces training and education officer
# Resume: Armed forces training and education officer
#
# Match Score: 13
# Job: Civil Service fast streamer
# Resume: Civil Service fast streamer
#
# Match Score: 13
# Job: Research scientist (life sciences)
# Resume: Patent attorney
#
# Match Score: 12
# Job: Armed forces logistics/support/administrative officer
# Resume: Armed forces operational officer
#
# Match Score: 12
# Job: Armed forces training and education officer
# Resume: Armed forces operational officer
#
# Match Score: 12
# Job: Primary school teacher
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 12
# Job: Community development worker
# Resume: Product/process development scientist
#
# Match Score: 12
# Job: Community arts worker
# Resume: Product/process development scientist
#
# Match Score: 12
# Job: Community arts worker
# Resume: Product/process development scientist
#
# Match Score: 12
# Job: Commercial art gallery manager
# Resume: Commercial art gallery manager
#
# Match Score: 12
# Job: Armed forces training and education officer
# Resume: Armed forces training and education officer
#
# Match Score: 12
# Job: IT sales professional
# Resume: IT sales professional
#
# Match Score: 12
# Job: Diplomatic Services operational officer
# Resume: Diplomatic Services operational officer
#
# Match Score: 12
# Job: Radio broadcast assistant
# Resume: Solicitor
#
# Match Score: 12
# Job: Administrator, Civil Service
# Resume: Administrator
#
# Match Score: 12
# Job: Psychologist, prison and probation services
# Resume: Psychologist, prison and probation services
#
# Match Score: 12
# Job: Administrator, Civil Service
# Resume: Administrator, Civil Service
#
# Match Score: 12
# Job: Armed forces logistics/support/administrative officer
# Resume: Armed forces training and education officer
#
# Match Score: 12
# Job: Community development worker
# Resume: Armed forces training and education officer
#
# Match Score: 12
# Job: Armed forces logistics/support/administrative officer
# Resume: Armed forces operational officer
#
# Match Score: 12
# Job: Armed forces training and education officer
# Resume: Armed forces operational officer
#
# Match Score: 11
# Job: Designer, jewellery
# Resume: Learning mentor
#
# Match Score: 11
# Job: Scientist, research (maths)
# Resume: Lobbyist
#
# Match Score: 11
# Job: Bonds trader
# Resume: Lobbyist
#
# Match Score: 11
# Job: Scientist, research (life sciences)
# Resume: Lobbyist
#
# Match Score: 11
# Job: Scientist, research (medical)
# Resume: Lobbyist
#
# Match Score: 11
# Job: Psychotherapist, dance movement
# Resume: Designer, jewellery
#
# Match Score: 11
# Job: Technical sales engineer
# Resume: Technical sales engineer
#
# Match Score: 11
# Job: Restaurant manager, fast food
# Resume: Dispensing optician
#
# Match Score: 11
# Job: Lecturer, higher education
# Resume: Lecturer, higher education
#
# Match Score: 11
# Job: Clinical scientist, histocompatibility and immunogenetics
# Resume: Further education lecturer
#
# Match Score: 11
# Job: Diplomatic Services operational officer
# Resume: Armed forces operational officer
#
# Match Score: 11
# Job: Biomedical engineer
# Resume: Biomedical engineer
#
# Match Score: 11
# Job: Biomedical engineer
# Resume: Biomedical engineer
#
# Match Score: 11
# Job: Teacher, special educational needs
# Resume: Psychotherapist, dance movement
#
# Match Score: 11
# Job: IT consultant
# Resume: Environmental health practitioner
#
# Match Score: 11
# Job: Research officer, trade union
# Resume: Research officer, trade union
#
# Match Score: 11
# Job: Psychotherapist, dance movement
# Resume: Psychotherapist, dance movement
#
# Match Score: 11
# Job: Public librarian
# Resume: Public librarian
#
# Match Score: 11
# Job: Insurance broker
# Resume: Public librarian
#
# Match Score: 11
# Job: Passenger transport manager
# Resume: Passenger transport manager
#
# Match Score: 11
# Job: Biomedical engineer
# Resume: Environmental health practitioner
#
# Match Score: 11
# Job: Biomedical engineer
# Resume: Environmental health practitioner
#
# Match Score: 11
# Job: Administrator, arts
# Resume: Administrator, arts
#
# Match Score: 11
# Job: Pharmacist, hospital
# Resume: Administrator, arts
#
# Match Score: 11
# Job: Teacher, adult education
# Resume: Teacher, adult education
#
# Match Score: 11
# Job: Production designer, theatre/television/film
# Resume: Psychologist, prison and probation services
#
# Match Score: 11
# Job: Learning disability nurse
# Resume: Artist
#
# Match Score: 11
# Job: Higher education careers adviser
# Resume: Higher education careers adviser
#
# Match Score: 11
# Job: Optician, dispensing
# Resume: Communications engineer
#
# Match Score: 11
# Job: Licensed conveyancer
# Resume: Presenter, broadcasting
#
# Match Score: 11
# Job: Production assistant, television
# Resume: Sales professional, IT
#
# Match Score: 11
# Job: Engineer, control and instrumentation
# Resume: Diplomatic Services operational officer
#
# Match Score: 11
# Job: Engineer, control and instrumentation
# Resume: Diplomatic Services operational officer
#
# Match Score: 11
# Job: Research scientist (medical)
# Resume: Astronomer
#
# Match Score: 11
# Job: Insurance broker
# Resume: Astronomer
#
# Match Score: 11
# Job: Research scientist (medical)
# Resume: Astronomer
#
# Match Score: 11
# Job: Administrator, Civil Service
# Resume: Civil Service fast streamer
#
# Match Score: 11
# Job: Media planner
# Resume: Civil Service fast streamer
#
# Match Score: 11
# Job: Sports development officer
# Resume: Sports development officer
#
# Match Score: 11
# Job: Sports development officer
# Resume: Sports development officer
#
# Match Score: 11
# Job: Theatre stage manager
# Resume: Solicitor
#
# Match Score: 11
# Job: Conservator, furniture
# Resume: Careers information officer
#
# Match Score: 11
# Job: Public relations account executive
# Resume: Careers information officer
#
# Match Score: 11
# Job: Public relations account executive
# Resume: Careers information officer
#
# Match Score: 11
# Job: Hospital doctor
# Resume: Careers information officer
#
# Match Score: 11
# Job: Financial manager
# Resume: Fitness centre manager
#
# Match Score: 11
# Job: Public relations account executive
# Resume: Fitness centre manager
#
# Match Score: 11
# Job: Public relations account executive
# Resume: Fitness centre manager
#
# Match Score: 11
# Job: Special educational needs teacher
# Resume: Commissioning editor
#
# Match Score: 11
# Job: Teacher, special educational needs
# Resume: Commissioning editor
#
# Match Score: 11
# Job: Civil Service fast streamer
# Resume: Administrator
#
# Match Score: 11
# Job: Publishing copy
# Resume: Publishing copy
#
# Match Score: 11
# Job: Biochemist, clinical
# Resume: Biochemist, clinical
#
# Match Score: 11
# Job: Diplomatic Services operational officer
# Resume: Forensic psychologist
#
# Match Score: 11
# Job: Teacher, primary school
# Resume: Doctor, general practice
#
# Match Score: 11
# Job: Biomedical engineer
# Resume: Chemical engineer
#
# Match Score: 11
# Job: Biomedical engineer
# Resume: Chemical engineer
#
# Match Score: 11
# Job: Teacher, English as a foreign language
# Resume: Insurance risk surveyor
#
# Match Score: 11
# Job: Civil Service fast streamer
# Resume: Administrator, Civil Service
#
# Match Score: 11
# Job: Media planner
# Resume: Media planner
#
# Match Score: 11
# Job: Radio broadcast assistant
# Resume: Data processing manager
#
# Match Score: 11
# Job: Estate manager/land agent
# Resume: Print production planner
#
# Match Score: 11
# Job: English as a second language teacher
# Resume: Health and safety adviser
#
# Match Score: 11
# Job: Medical technical officer
# Resume: Health and safety adviser
#
# Match Score: 11
# Job: Health and safety inspector
# Resume: Health and safety adviser
#
# Match Score: 11
# Job: Civil engineer, consulting
# Resume: Engineer, manufacturing
#
# Match Score: 11
# Job: Engineer, manufacturing systems
# Resume: Engineer, manufacturing
#
# Match Score: 11
# Job: Veterinary surgeon
# Resume: Armed forces training and education officer
#
# Match Score: 11
# Job: Training and development officer
# Resume: Armed forces training and education officer
#
# Match Score: 11
# Job: Community arts worker
# Resume: Armed forces training and education officer
#
# Match Score: 11
# Job: Community arts worker
# Resume: Armed forces training and education officer
#
# Match Score: 11
# Job: Surveyor, quantity
# Resume: Armed forces training and education officer
#
# Match Score: 11
# Job: Computer games developer
# Resume: Computer games developer
#
# Match Score: 11
# Job: Teacher, primary school
# Resume: Building services engineer
#
# Match Score: 11
# Job: Sales professional, IT
# Resume: Press sub
#
# Match Score: 11
# Job: Biomedical engineer
# Resume: Press sub
#
# Match Score: 11
# Job: Press sub
# Resume: Press sub
#
# Match Score: 11
# Job: IT sales professional
# Resume: Press sub
#
# Match Score: 11
# Job: Biomedical engineer
# Resume: Press sub
#
# Match Score: 11
# Job: Chemist, analytical
# Resume: Patent attorney
#
# Match Score: 11
# Job: Scientist, research (life sciences)
# Resume: Patent attorney
#
# Match Score: 11
# Job: Lighting technician, broadcasting/film/video
# Resume: Patent attorney
#
# Match Score: 11
# Job: Scientist, research (physical sciences)
# Resume: Chief Financial Officer
#
# Match Score: 11
# Job: Scientist, research (physical sciences)
# Resume: Chief Financial Officer
#
# Match Score: 11
# Job: Scientist, product/process development
# Resume: Scientist, clinical (histocompatibility and immunogenetics)
#
# Match Score: 11
# Job: Chief Marketing Officer
# Resume: Building control surveyor
#
# Match Score: 11
# Job: Chief Operating Officer
# Resume: Building control surveyor
#
# Match Score: 11
# Job: Chief Technology Officer
# Resume: Building control surveyor
#
# Match Score: 11
# Job: Computer games developer
# Resume: Computer games developer
#
# Match Score: 11
# Job: Scientist, research (maths)
# Resume: Scientist, research (maths)
#
# Match Score: 11
# Job: Chief Operating Officer
# Resume: Dietitian
#
# Match Score: 11
# Job: Armed forces technical officer
# Resume: Accountant, chartered public finance
#
# Match Score: 11
# Job: Energy manager
# Resume: Forest/woodland manager
#
# Match Score: 11
# Job: Energy engineer
# Resume: Forest/woodland manager
#
# Match Score: 11
# Job: Engineer, control and instrumentation
# Resume: Rural practice surveyor
#
# Match Score: 11
# Job: Engineer, control and instrumentation
# Resume: Rural practice surveyor
#
# Match Score: 11
# Job: Health and safety inspector
# Resume: Rural practice surveyor
#
# Match Score: 11
# Job: Quantity surveyor
# Resume: Furniture designer
#
# Match Score: 11
# Job: Diplomatic Services operational officer
# Resume: Armed forces operational officer
#
# Match Score: 11
# Job: Freight forwarder
# Resume: Building surveyor
#
# Match Score: 11
# Job: English as a foreign language teacher
# Resume: Public house manager
#
# Match Score: 11
# Job: Production engineer
# Resume: Production engineer
#
# Match Score: 11
# Job: Biomedical engineer
# Resume: Production engineer
#
# Match Score: 11
# Job: Biomedical engineer
# Resume: Production engineer
#
# Match Score: 10
# Job: Media buyer
# Resume: Scientist, clinical (histocompatibility and immunogenetics)
#
# Match Score: 10
# Job: Media buyer
# Resume: Scientist, clinical (histocompatibility and immunogenetics)
#
# Match Score: 10
# Job: Public house manager
# Resume: Learning mentor
#
# Match Score: 10
# Job: Forest/woodland manager
# Resume: Learning mentor
#
# Match Score: 10
# Job: Energy manager
# Resume: Learning mentor
#
# Match Score: 10
# Job: Stage manager
# Resume: Learning mentor
#
# Match Score: 10
# Job: Restaurant manager, fast food
# Resume: Learning mentor
#
# Match Score: 10
# Job: Production manager
# Resume: Learning mentor
#
# Match Score: 10
# Job: Designer, graphic
# Resume: Learning mentor
#
# Match Score: 10
# Job: Purchasing manager
# Resume: Learning mentor
#
# Match Score: 10
# Job: Scientist, product/process development
# Resume: Lobbyist
#
# Match Score: 10
# Job: Scientist, research (physical sciences)
# Resume: Lobbyist
#
# Match Score: 10
# Job: Scientist, forensic
# Resume: Lobbyist
#
# Match Score: 10
# Job: Physicist, medical
# Resume: Lobbyist
#
# Match Score: 10
# Job: Television camera operator
# Resume: Television camera operator
#
# Match Score: 10
# Job: Television camera operator
# Resume: Television camera operator
#
# Match Score: 10
# Job: Sport and exercise psychologist
# Resume: Veterinary surgeon
#
# Match Score: 10
# Job: Equities trader
# Resume: Oncologist
#
# Match Score: 10
# Job: Site engineer
# Resume: Aeronautical engineer
#
# Match Score: 10
# Job: Civil engineer, consulting
# Resume: Aeronautical engineer
#
# Match Score: 10
# Job: Petroleum engineer
# Resume: Aeronautical engineer
#
# Match Score: 10
# Job: Energy engineer
# Resume: Aeronautical engineer
#
# Match Score: 10
# Job: Engineer, automotive
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Scientist, research (maths)
# Resume: Arboriculturist
#
# Match Score: 10
# Job: Health promotion specialist
# Resume: Arboriculturist
#
# Match Score: 10
# Job: Chief Marketing Officer
# Resume: Network engineer
#
# Match Score: 10
# Job: Chief Operating Officer
# Resume: Network engineer
#
# Match Score: 10
# Job: Chartered public finance accountant
# Resume: Network engineer
#
# Match Score: 10
# Job: Chief Technology Officer
# Resume: Network engineer
#
# Match Score: 10
# Job: Radiographer, diagnostic
# Resume: Theatre manager
#
# Match Score: 10
# Job: Financial manager
# Resume: Theatre manager
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Theatre manager
#
# Match Score: 10
# Job: Tour manager
# Resume: Theatre manager
#
# Match Score: 10
# Job: Records manager
# Resume: Theatre manager
#
# Match Score: 10
# Job: Quality manager
# Resume: Theatre manager
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Theatre manager
#
# Match Score: 10
# Job: Surveyor, quantity
# Resume: Theatre manager
#
# Match Score: 10
# Job: Environmental manager
# Resume: Theatre manager
#
# Match Score: 10
# Job: Theatre stage manager
# Resume: Theatre manager
#
# Match Score: 10
# Job: Financial manager
# Resume: Risk manager
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Risk manager
#
# Match Score: 10
# Job: Tour manager
# Resume: Risk manager
#
# Match Score: 10
# Job: Computer games developer
# Resume: Risk manager
#
# Match Score: 10
# Job: Records manager
# Resume: Risk manager
#
# Match Score: 10
# Job: Systems developer
# Resume: Risk manager
#
# Match Score: 10
# Job: Systems developer
# Resume: Risk manager
#
# Match Score: 10
# Job: Quality manager
# Resume: Risk manager
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Risk manager
#
# Match Score: 10
# Job: Environmental manager
# Resume: Risk manager
#
# Match Score: 10
# Job: Designer, graphic
# Resume: Archaeologist
#
# Match Score: 10
# Job: Psychologist, prison and probation services
# Resume: Nurse, learning disability
#
# Match Score: 10
# Job: Sports development officer
# Resume: Sports development officer
#
# Match Score: 10
# Job: Sports development officer
# Resume: Sports development officer
#
# Match Score: 10
# Job: Chief Marketing Officer
# Resume: Sound technician, broadcasting/film/video
#
# Match Score: 10
# Job: Chief Operating Officer
# Resume: Sound technician, broadcasting/film/video
#
# Match Score: 10
# Job: Chief Technology Officer
# Resume: Sound technician, broadcasting/film/video
#
# Match Score: 10
# Job: Scientist, research (physical sciences)
# Resume: Energy engineer
#
# Match Score: 10
# Job: Scientist, research (physical sciences)
# Resume: Energy engineer
#
# Match Score: 10
# Job: Scientist, product/process development
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Scientist, marine
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Community development worker
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Adult guidance worker
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Community arts worker
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Scientist, research (life sciences)
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Community arts worker
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Advice worker
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Advice worker
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Adult guidance worker
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Advertising account planner
# Resume: Advertising account planner
#
# Match Score: 10
# Job: Advertising copywriter
# Resume: Advertising account planner
#
# Match Score: 10
# Job: Radio producer
# Resume: Prison officer
#
# Match Score: 10
# Job: Nature conservation officer
# Resume: Armed forces operational officer
#
# Match Score: 10
# Job: Recycling officer
# Resume: Armed forces operational officer
#
# Match Score: 10
# Job: Training and development officer
# Resume: Armed forces operational officer
#
# Match Score: 10
# Job: Tourism officer
# Resume: Armed forces operational officer
#
# Match Score: 10
# Job: Medical technical officer
# Resume: Armed forces operational officer
#
# Match Score: 10
# Job: Waste management officer
# Resume: Armed forces operational officer
#
# Match Score: 10
# Job: Waste management officer
# Resume: Armed forces operational officer
#
# Match Score: 10
# Job: Trading standards officer
# Resume: Armed forces operational officer
#
# Match Score: 10
# Job: Structural engineer
# Resume: Biomedical engineer
#
# Match Score: 10
# Job: Production engineer
# Resume: Biomedical engineer
#
# Match Score: 10
# Job: Financial manager
# Resume: Catering manager
#
# Match Score: 10
# Job: Tour manager
# Resume: Catering manager
#
# Match Score: 10
# Job: Records manager
# Resume: Catering manager
#
# Match Score: 10
# Job: Archaeologist
# Resume: Catering manager
#
# Match Score: 10
# Job: Quality manager
# Resume: Catering manager
#
# Match Score: 10
# Job: Environmental manager
# Resume: Catering manager
#
# Match Score: 10
# Job: Accountant, chartered management
# Resume: Midwife
#
# Match Score: 10
# Job: Accountant, chartered management
# Resume: Midwife
#
# Match Score: 10
# Job: Armed forces technical officer
# Resume: Medical technical officer
#
# Match Score: 10
# Job: Press sub
# Resume: Camera operator
#
# Match Score: 10
# Job: Armed forces logistics/support/administrative officer
# Resume: Geochemist
#
# Match Score: 10
# Job: Nature conservation officer
# Resume: Geochemist
#
# Match Score: 10
# Job: Diplomatic Services operational officer
# Resume: Geochemist
#
# Match Score: 10
# Job: Financial manager
# Resume: Geochemist
#
# Match Score: 10
# Job: Recycling officer
# Resume: Geochemist
#
# Match Score: 10
# Job: Training and development officer
# Resume: Geochemist
#
# Match Score: 10
# Job: Speech and language therapist
# Resume: Geochemist
#
# Match Score: 10
# Job: Tour manager
# Resume: Geochemist
#
# Match Score: 10
# Job: Records manager
# Resume: Geochemist
#
# Match Score: 10
# Job: Tourism officer
# Resume: Geochemist
#
# Match Score: 10
# Job: Quality manager
# Resume: Geochemist
#
# Match Score: 10
# Job: Medical technical officer
# Resume: Geochemist
#
# Match Score: 10
# Job: Waste management officer
# Resume: Geochemist
#
# Match Score: 10
# Job: Armed forces training and education officer
# Resume: Geochemist
#
# Match Score: 10
# Job: Waste management officer
# Resume: Geochemist
#
# Match Score: 10
# Job: Trading standards officer
# Resume: Geochemist
#
# Match Score: 10
# Job: Environmental manager
# Resume: Geochemist
#
# Match Score: 10
# Job: Psychotherapist, dance movement
# Resume: Broadcast presenter
#
# Match Score: 10
# Job: Psychotherapist, dance movement
# Resume: Psychotherapist, dance movement
#
# Match Score: 10
# Job: Engineer, maintenance (IT)
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: Horticultural consultant
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: IT sales professional
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: Environmental manager
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: Control and instrumentation engineer
# Resume: Control and instrumentation engineer
#
# Match Score: 10
# Job: Administrator, local government
# Resume: Administrator, local government
#
# Match Score: 10
# Job: Teacher, primary school
# Resume: Product designer
#
# Match Score: 10
# Job: Administrator, arts
# Resume: Administrator, sports
#
# Match Score: 10
# Job: Administrator, Civil Service
# Resume: Administrator, sports
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Administrator, sports
#
# Match Score: 10
# Job: Community development worker
# Resume: Administrator, sports
#
# Match Score: 10
# Job: Administrator, local government
# Resume: Administrator, sports
#
# Match Score: 10
# Job: Community arts worker
# Resume: Administrator, sports
#
# Match Score: 10
# Job: Community arts worker
# Resume: Administrator, sports
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Administrator, sports
#
# Match Score: 10
# Job: Engineer, materials
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Engineer, maintenance (IT)
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Engineer, water
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Scientist, product/process development
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Scientist, marine
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Research scientist (medical)
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Research scientist (medical)
# Resume: Engineer, broadcasting (operations)
#
# Match Score: 10
# Job: Administrator, arts
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Soil scientist
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Production designer, theatre/television/film
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Scientist, product/process development
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Training and development officer
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Physiological scientist
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Adult guidance worker
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Research scientist (medical)
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Advice worker
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Audiological scientist
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Advice worker
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Adult guidance worker
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Research scientist (medical)
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Data scientist
# Resume: Product/process development scientist
#
# Match Score: 10
# Job: Telecommunications researcher
# Resume: Commercial art gallery manager
#
# Match Score: 10
# Job: Financial manager
# Resume: Commercial art gallery manager
#
# Match Score: 10
# Job: Tour manager
# Resume: Commercial art gallery manager
#
# Match Score: 10
# Job: Records manager
# Resume: Commercial art gallery manager
#
# Match Score: 10
# Job: Quality manager
# Resume: Commercial art gallery manager
#
# Match Score: 10
# Job: Surveyor, quantity
# Resume: Commercial art gallery manager
#
# Match Score: 10
# Job: Environmental manager
# Resume: Commercial art gallery manager
#
# Match Score: 10
# Job: Advertising copywriter
# Resume: Engineer, manufacturing systems
#
# Match Score: 10
# Job: Therapist, nutritional
# Resume: Chief Financial Officer
#
# Match Score: 10
# Job: Armed forces technical officer
# Resume: Translator
#
# Match Score: 10
# Job: Speech and language therapist
# Resume: Quality manager
#
# Match Score: 10
# Job: Nurse, mental health
# Resume: Broadcast presenter
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Multimedia specialist
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Multimedia specialist
#
# Match Score: 10
# Job: Engineer, materials
# Resume: Public librarian
#
# Match Score: 10
# Job: Engineer, maintenance (IT)
# Resume: Public librarian
#
# Match Score: 10
# Job: Engineer, water
# Resume: Public librarian
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Public librarian
#
# Match Score: 10
# Job: Insurance underwriter
# Resume: Public librarian
#
# Match Score: 10
# Job: IT sales professional
# Resume: Public librarian
#
# Match Score: 10
# Job: Ship broker
# Resume: Public librarian
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Public librarian
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Public librarian
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Public librarian
#
# Match Score: 10
# Job: Medical technical officer
# Resume: Public librarian
#
# Match Score: 10
# Job: Public relations account executive
# Resume: Public librarian
#
# Match Score: 10
# Job: Public relations account executive
# Resume: Public librarian
#
# Match Score: 10
# Job: Secondary school teacher
# Resume: Minerals surveyor
#
# Match Score: 10
# Job: Medical technical officer
# Resume: Hospital doctor
#
# Match Score: 10
# Job: Civil engineer, consulting
# Resume: Theatre director
#
# Match Score: 10
# Job: Engineer, materials
# Resume: Engineer, electronics
#
# Match Score: 10
# Job: Engineer, maintenance (IT)
# Resume: Engineer, electronics
#
# Match Score: 10
# Job: Engineer, water
# Resume: Engineer, electronics
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Engineer, electronics
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Engineer, electronics
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Engineer, electronics
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Engineer, electronics
#
# Match Score: 10
# Job: Chief Marketing Officer
# Resume: Chief Strategy Officer
#
# Match Score: 10
# Job: Chief Operating Officer
# Resume: Chief Strategy Officer
#
# Match Score: 10
# Job: Chief Technology Officer
# Resume: Chief Strategy Officer
#
# Match Score: 10
# Job: Biochemist, clinical
# Resume: Copywriter, advertising
#
# Match Score: 10
# Job: Scientist, research (physical sciences)
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Scientist, research (physical sciences)
# Resume: Scientist, research (physical sciences)
#
# Match Score: 10
# Job: Structural engineer
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: Horticultural consultant
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: Production engineer
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: IT consultant
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: Environmental manager
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: Health and safety inspector
# Resume: Environmental health practitioner
#
# Match Score: 10
# Job: Radio producer
# Resume: Engineer, electrical
#
# Match Score: 10
# Job: Engineer, materials
# Resume: Engineer, materials
#
# Match Score: 10
# Job: Production engineer
# Resume: Engineer, materials
#
# Match Score: 10
# Job: Teacher, special educational needs
# Resume: Administrator, arts
#
# Match Score: 10
# Job: Administrator, Civil Service
# Resume: Administrator, arts
#
# Match Score: 10
# Job: Administrator, local government
# Resume: Administrator, arts
#
# Match Score: 10
# Job: Primary school teacher
# Resume: Administrator, arts
#
# Match Score: 10
# Job: Retail banker
# Resume: Administrator, arts
#
# Match Score: 10
# Job: Community arts worker
# Resume: Administrator, arts
#
# Match Score: 10
# Job: Community arts worker
# Resume: Administrator, arts
#
# Match Score: 10
# Job: Teacher, music
# Resume: Administrator, arts
#
# Match Score: 10
# Job: Teacher, primary school
# Resume: Teacher, secondary school
#
# Match Score: 10
# Job: Teacher, secondary school
# Resume: Teacher, secondary school
#
# Match Score: 10
# Job: Armed forces technical officer
# Resume: Armed forces training and education officer
#
# Match Score: 10
# Job: Engineer, maintenance (IT)
# Resume: IT sales professional
#
# Match Score: 10
# Job: Sales professional, IT
# Resume: IT sales professional
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: IT sales professional
#
# Match Score: 10
# Job: IT consultant
# Resume: IT sales professional
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: IT sales professional
#
# Match Score: 10
# Job: Administrator, arts
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Engineer, materials
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Engineer, maintenance (IT)
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Engineer, water
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Scientist, product/process development
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Scientist, marine
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Administrator, Civil Service
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Administrator, local government
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Engineer, chemical
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Engineer, control and instrumentation
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Engineer, electrical
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Armed forces training and education officer
# Resume: Engineer, automotive
#
# Match Score: 10
# Job: Armed forces logistics/support/administrative officer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Nature conservation officer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Diplomatic Services operational officer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Production engineer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Recycling officer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Training and development officer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Tourism officer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Medical technical officer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Waste management officer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Psychologist, sport and exercise
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Armed forces training and education officer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Waste management officer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Trading standards officer
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Bookseller
#
# Match Score: 10
# Job: Bookseller
# Resume: Bookseller
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Bookseller
#
# Match Score: 10
# Job: Psychologist, prison and probation services
# Resume: Psychologist, prison and probation services
#
# Match Score: 10
# Job: Health service manager
# Resume: Health service manager
#
# Match Score: 10
# Job: Chief Operating Officer
# Resume: Chief Operating Officer
#
# Match Score: 10
# Job: Health promotion specialist
# Resume: Chief Operating Officer
#
# Match Score: 10
# Job: Contracting civil engineer
# Resume: Careers information officer
#
# Match Score: 10
# Job: Veterinary surgeon
# Resume: Geologist, engineering
#
# Match Score: 10
# Job: Designer, multimedia
# Resume: Nurse, adult
#
# Match Score: 10
# Job: Nurse, adult
# Resume: Nurse, adult
#
# Match Score: 10
# Job: Public house manager
# Resume: Radio producer
#
# Match Score: 10
# Job: Armed forces technical officer
# Resume: Charity fundraiser
#
# Match Score: 10
# Job: Soil scientist
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Production designer, theatre/television/film
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Scientist, product/process development
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Production engineer
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Training and development officer
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Physiological scientist
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Community development worker
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Research scientist (medical)
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Personal assistant
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Radio broadcast assistant
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Audiological scientist
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Research scientist (medical)
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Data scientist
# Resume: Wellsite geologist
#
# Match Score: 10
# Job: Chemical engineer
# Resume: Physicist, medical
#
# Match Score: 10
# Job: Geographical information systems officer
# Resume: Physicist, medical
#
# Match Score: 10
# Job: Sports development officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Armed forces technical officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Prison officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Exhibitions officer, museum/gallery
# Resume: Communications engineer
#
# Match Score: 10
# Job: Site engineer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Civil engineer, consulting
# Resume: Communications engineer
#
# Match Score: 10
# Job: Recycling officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Sports development officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Human resources officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Health promotion specialist
# Resume: Communications engineer
#
# Match Score: 10
# Job: Petroleum engineer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Higher education careers adviser
# Resume: Communications engineer
#
# Match Score: 10
# Job: Financial adviser
# Resume: Communications engineer
#
# Match Score: 10
# Job: Nature conservation officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Medical technical officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Museum/gallery exhibitions officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Research officer, trade union
# Resume: Communications engineer
#
# Match Score: 10
# Job: Energy engineer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Armed forces training and education officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Fisheries officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Tourism officer
# Resume: Communications engineer
#
# Match Score: 10
# Job: Armed forces logistics/support/administrative officer
# Resume: Actor
#
# Match Score: 10
# Job: Structural engineer
# Resume: Presenter, broadcasting
#
# Match Score: 10
# Job: Production engineer
# Resume: Presenter, broadcasting
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Presenter, broadcasting
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Presenter, broadcasting
#
# Match Score: 10
# Job: Sales professional, IT
# Resume: Sales professional, IT
#
# Match Score: 10
# Job: Sales professional, IT
# Resume: Sales professional, IT
#
# Match Score: 10
# Job: Production designer, theatre/television/film
# Resume: Haematologist
#
# Match Score: 10
# Job: Haematologist
# Resume: Haematologist
#
# Match Score: 10
# Job: Scientist, product/process development
# Resume: Haematologist
#
# Match Score: 10
# Job: Production engineer
# Resume: Haematologist
#
# Match Score: 10
# Job: Scientist, marine
# Resume: Haematologist
#
# Match Score: 10
# Job: Personal assistant
# Resume: Haematologist
#
# Match Score: 10
# Job: Radio broadcast assistant
# Resume: Haematologist
#
# Match Score: 10
# Job: Teacher, English as a foreign language
# Resume: Make
#
# Match Score: 10
# Job: Petroleum engineer
# Resume: Occupational therapist
#
# Match Score: 10
# Job: Diplomatic Services operational officer
# Resume: Investment banker, operational
#
# Match Score: 10
# Job: Retail banker
# Resume: Investment banker, operational
#
# Match Score: 10
# Job: Research scientist (medical)
# Resume: Investment banker, operational
#
# Match Score: 10
# Job: Chartered accountant
# Resume: Investment banker, operational
#
# Match Score: 10
# Job: Research scientist (medical)
# Resume: Investment banker, operational
#
# Match Score: 10
# Job: Scientist, product/process development
# Resume: Planning and development surveyor
#
# Match Score: 10
# Job: Training and development officer
# Resume: Planning and development surveyor
#
# Match Score: 10
# Job: Community development worker
# Resume: Planning and development surveyor
#
# Match Score: 10
# Job: Quantity surveyor
# Resume: Planning and development surveyor
#
# Match Score: 10
# Job: Soil scientist
# Resume: Astronomer
#
# Match Score: 10
# Job: Designer, textile
# Resume: Astronomer
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Astronomer
#
# Match Score: 10
# Job: Physiological scientist
# Resume: Astronomer
#
# Match Score: 10
# Job: Community development worker
# Resume: Astronomer
#
# Match Score: 10
# Job: Astronomer
# Resume: Astronomer
#
# Match Score: 10
# Job: Insurance underwriter
# Resume: Astronomer
#
# Match Score: 10
# Job: Adult guidance worker
# Resume: Astronomer
#
# Match Score: 10
# Job: Designer, industrial/product
# Resume: Astronomer
#
# Match Score: 10
# Job: Ship broker
# Resume: Astronomer
#
# Match Score: 10
# Job: Community arts worker
# Resume: Astronomer
#
# Match Score: 10
# Job: Community arts worker
# Resume: Astronomer
#
# Match Score: 10
# Job: Designer, graphic
# Resume: Astronomer
#
# Match Score: 10
# Job: Biomedical engineer
# Resume: Astronomer
#
# Match Score: 10
# Job: Designer, jewellery
# Resume: Astronomer
#
# Match Score: 10
# Job: Advice worker
# Resume: Astronomer
#
# Match Score: 10
# Job: Audiological scientist
# Resume: Astronomer
#
# Match Score: 10
# Job: Advice worker
# Resume: Astronomer
#
# Match Score: 10
# Job: Adult guidance worker
# Resume: Astronomer
#
# Match Score: 10
# Job: Data scientist
# Resume: Astronomer
#
# Match Score: 10
# Job: Financial manager
# Resume: Leisure centre manager
#
# Match Score: 10
# Job: Tour manager
# Resume: Leisure centre manager
#
# Match Score: 10
# Job: Records manager
# Resume: Leisure centre manager
#
# Match Score: 10
# Job: Quality manager
# Resume: Leisure centre manager
#
# Match Score: 10
# Job: Environmental manager
# Resume: Leisure centre manager
#
# Match Score: 10
# Job: Chartered public finance accountant
# Resume: Animal technologist
#
# Match Score: 10
# Job: Optician, dispensing
# Resume: Animal technologist
#
# Match Score: 10
# Job: Research officer, government
# Resume: Clinical biochemist
#
# Match Score: 10
# Job: Town planner
# Resume: Civil Service fast streamer
#
# Match Score: 10
# Job: Media buyer
# Resume: Civil Service fast streamer
#
# Match Score: 10
# Job: Media buyer
# Resume: Civil Service fast streamer
#
# Match Score: 10
# Job: Community development worker
# Resume: Community development worker
#
# Match Score: 10
# Job: Engineer, maintenance (IT)
# Resume: Equities trader
#
# Match Score: 10
# Job: Financial manager
# Resume: Solicitor
#
# Match Score: 10
# Job: Tour manager
# Resume: Solicitor
#
# Match Score: 10
# Job: Records manager
# Resume: Solicitor
#
# Match Score: 10
# Job: Quality manager
# Resume: Solicitor
#
# Match Score: 10
# Job: Personal assistant
# Resume: Solicitor
#
# Match Score: 10
# Job: Environmental manager
# Resume: Solicitor
#
# Match Score: 10
# Job: Estate manager/land agent
# Resume: Art gallery manager
#
# Match Score: 10
# Job: Telecommunications researcher
# Resume: Regulatory affairs officer
#
# Match Score: 10
# Job: Armed forces logistics/support/administrative officer
# Resume: Regulatory affairs officer
#
# Match Score: 10
# Job: Horticultural consultant
# Resume: Regulatory affairs officer
#
# Match Score: 10
# Job: Nature conservation officer
# Resume: Regulatory affairs officer
#
# Match Score: 10
# Job: Diplomatic Services operational officer
# Resume: Regulatory affairs officer
#
# Match Score: 10
# Job: Public librarian
# Resume: Regulatory affairs officer
#
# Match Score: 10
# Job: Recycling officer
# Resume: Regulatory affairs officer
#
# Match Score: 10
# Job: Training and development officer
# Resume: Regulatory affairs officer
#
# Match Score: 10
# Job: IT consultant
# Resume: Regulatory affairs officer
#
# Match Score: 10
# Job: Tourism officer
# Resume: Regulatory affairs officer
#
# Match Score: 10
# Job: Quantity surveyor
# Resume: Regulatory affairs officer

# %%
resume_mapping = {
    "settings": {
        "analysis": {
            "analyzer": {
                "custom_analyzer": {
                    "type": "custom",
                    "tokenizer": "whitespace",
                    "filter": ["lowercase"]
                }
            }
        }
    },
    "mappings": {
        "properties": {
            "Skills": {"type": "text", "analyzer": "custom_analyzer"},
            "Experience": {
                "type": "nested",
                "properties": {
                    "title": {"type": "text", "analyzer": "custom_analyzer"},
                    "duration": {"type": "text", "analyzer": "custom_analyzer"}
                }
            },
            "Education": {"type": "text", "analyzer": "custom_analyzer"}
        }
    }
}

# %%
from elasticsearch import Elasticsearch

# Connect to Elasticsearch
es = Elasticsearch("http://localhost:9200")

# Define custom analyzer (if needed)
custom_analyzer = {
    "analyzer": {
        "custom_lowercase_analyzer": {
            "type": "custom",
            "tokenizer": "standard",
            "filter": ["lowercase"]
        }
    }
}

# Define mapping for job listing index
job_mapping = {
    "settings": {
        "analysis": {
            "analyzer": {
                "custom_lowercase_analyzer": {
                    "type": "custom",
                    "tokenizer": "standard",
                    "filter": ["lowercase"]
                }
            }
        }
    },
    "mappings": {
        "properties": {
            "required_skills": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "experience_title": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "required_education": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "keywords": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "provider": {"type": "text", "analyzer": "custom_lowercase_analyzer"}  # New field
        }
    }
}

resume_mapping = {
    "settings": custom_analyzer,
    "mappings": {
        "properties": {
            "skills": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "experience": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "education": {"type": "text", "analyzer": "custom_lowercase_analyzer"},
            "keywords": {"type": "text", "analyzer": "custom_lowercase_analyzer"}
        }
    }
}

# %%
from elasticsearch import Elasticsearch, helpers

es = Elasticsearch("http://localhost:9200")



def job_data_generator(job_data):
    for job in job_data:
        yield {
            "_index": "job_listings",
            "_id": job.get("id"),
            "_source": job
        }

es.indices.delete(index='job_listings', ignore=[400, 404])

# Create the new index with the updated mapping
es.indices.create(index='job_listings', body=job_mapping)

# Re-index your job data
helpers.bulk(es, job_data_generator(jobs_data))





# Function to create a generator yielding resume data for bulk indexing
def resume_data_generator(resume_data):
    for resume in resume_data:
        yield {
            "_index": "resumes",
            "_id": resume.get("id"),  # Assuming each resume has a unique 'id' field
            "_source": resume
        }





# Bulk indexing resume data
helpers.bulk(es, resume_data_generator(synthetic_resumes))

print("Indexing complete.")
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_20176\1501628427.py:15: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   es.indices.delete(index='job_listings', ignore=[400, 404])
# C:\Users\acer\AppData\Local\Temp\ipykernel_20176\1501628427.py:15: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.15/security-minimal-setup.html to enable security.
#   es.indices.delete(index='job_listings', ignore=[400, 404])
# C:\Users\acer\AppData\Local\Temp\ipykernel_20176\1501628427.py:18: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.15/security-minimal-setup.html to enable security.
#   es.indices.create(index='job_listings', body=job_mapping)
# C:\Users\acer\AppData\Local\Temp\ipykernel_20176\1501628427.py:21: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.15/security-minimal-setup.html to enable security.
#   helpers.bulk(es, job_data_generator(jobs_data))
# Indexing complete.
# C:\Users\acer\AppData\Local\Temp\ipykernel_20176\1501628427.py:41: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.15/security-minimal-setup.html to enable security.
#   helpers.bulk(es, resume_data_generator(synthetic_resumes))

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch("http://localhost:9200")

input_resume = {
    "skills": ['Java', 'C++'],  # Multiple relevant skills
    "education": "Bachelor's in Software",
    "experience": "Electrical"  # Optional: Include if experience titles are relevant
}

# Formulate a more targeted but not overly complex search query
query_body = {
    "query": {
        "bool": {
            "should": [
                {"match": {"required_skills": {"query": skill, "boost": 1.2}} for skill in input_resume["skills"]},
                {"match_phrase": {"required_education": input_resume["education"]}},
                # Optional: Include if experience titles are relevant
                {"match": {"experience_title": input_resume["experience"]}}
            ],
            "minimum_should_match": 1
        }
    },
    "size": 100  # Adjust the number of results as needed
}

# Search the job listings index
results = es.search(index="job_listings", body=query_body)

# Print the matched job listings
print("Matched Job Listings:")
for hit in results['hits']['hits']:
    job_listing = hit['_source']
    provider = job_listing.get('provider', 'Unknown Provider')  # Default to 'Unknown Provider' if not present
    print(f"Job Title: {job_listing['experience_title']}, Provider: {job_listing.get('provider', 'Unknown')}, Score: {hit['_score']}")
# Out:
# Matched Job Listings:
# Job Title: Engineer, electrical, Provider: Provider V, Score: 6.044683
# Job Title: Electrical engineer, Provider: Provider Y, Score: 6.044683
# Job Title: Engineer, electrical, Provider: Provider D, Score: 6.044683
# Job Title: Animator, Provider: Provider R, Score: 3.345244
# Job Title: Agricultural engineer, Provider: Provider I, Score: 3.345244
# Job Title: Production assistant, television, Provider: Provider T, Score: 3.345244
# Job Title: Contractor, Provider: Provider P, Score: 3.345244
# Job Title: Occupational psychologist, Provider: Provider V, Score: 3.345244
# Job Title: Higher education careers adviser, Provider: Provider D, Score: 3.345244
# Job Title: Firefighter, Provider: Provider W, Score: 3.345244
# Job Title: Child psychotherapist, Provider: Provider F, Score: 3.345244
# Job Title: Theatre manager, Provider: Provider C, Score: 3.345244
# Job Title: Special effects artist, Provider: Provider O, Score: 2.9905787
# Job Title: Financial adviser, Provider: Provider C, Score: 2.9905787
# Job Title: Sports administrator, Provider: Provider Z, Score: 2.9905787
# Job Title: Herpetologist, Provider: Provider J, Score: 2.9905787
# Job Title: Osteopath, Provider: Provider E, Score: 2.9905787
# Job Title: Special educational needs teacher, Provider: Provider R, Score: 2.9905787
# Job Title: Recruitment consultant, Provider: Provider B, Score: 2.9905787
# Job Title: Sports development officer, Provider: Provider M, Score: 2.9905787
# Job Title: Engineer, chemical, Provider: Provider U, Score: 2.9905787
# Job Title: Community pharmacist, Provider: Provider J, Score: 2.9905787
# Job Title: Research scientist (physical sciences), Provider: Provider N, Score: 2.9905787
# Job Title: Sales promotion account executive, Provider: Provider X, Score: 2.9905787
# Job Title: Pensions consultant, Provider: Provider Y, Score: 2.9905787
# Job Title: Personnel officer, Provider: Provider D, Score: 2.9905787
# Job Title: Air traffic controller, Provider: Provider J, Score: 2.9905787
# Job Title: Scientific laboratory technician, Provider: Provider F, Score: 2.9905787
# Job Title: General practice doctor, Provider: Provider Q, Score: 2.9905787
# Job Title: Medical laboratory scientific officer, Provider: Provider D, Score: 2.9905787
# Job Title: Producer, television/film/video, Provider: Provider Y, Score: 2.9905787
# Job Title: Exercise physiologist, Provider: Provider H, Score: 2.9905787
# Job Title: Hotel manager, Provider: Provider I, Score: 2.9905787
# Job Title: Petroleum engineer, Provider: Provider J, Score: 2.703908
# Job Title: Medical illustrator, Provider: Provider L, Score: 2.703908
# Job Title: Optometrist, Provider: Provider A, Score: 2.703908
# Job Title: Management consultant, Provider: Provider G, Score: 2.703908
# Job Title: Osteopath, Provider: Provider Z, Score: 2.703908
# Job Title: Local government officer, Provider: Provider Q, Score: 2.703908
# Job Title: Immigration officer, Provider: Provider F, Score: 2.703908
# Job Title: Soil scientist, Provider: Provider Q, Score: 2.703908
# Job Title: Sport and exercise psychologist, Provider: Provider B, Score: 2.703908
# Job Title: Sales promotion account executive, Provider: Provider C, Score: 2.703908
# Job Title: Musician, Provider: Provider M, Score: 2.703908
# Job Title: Retail merchandiser, Provider: Provider F, Score: 2.703908
# Job Title: Teacher, English as a foreign language, Provider: Provider N, Score: 2.703908
# Job Title: Media buyer, Provider: Provider Y, Score: 2.703908
# Job Title: Secretary/administrator, Provider: Provider S, Score: 2.703908
# Job Title: Analytical chemist, Provider: Provider G, Score: 2.703908
# Job Title: Web designer, Provider: Provider O, Score: 2.703908
# Job Title: Social worker, Provider: Provider P, Score: 2.703908
# Job Title: Dealer, Provider: Provider G, Score: 2.703908
# Job Title: Education officer, museum, Provider: Provider P, Score: 2.703908
# Job Title: Information officer, Provider: Provider C, Score: 2.703908
# Job Title: Freight forwarder, Provider: Provider U, Score: 2.703908
# Job Title: Counsellor, Provider: Provider I, Score: 2.703908
# Job Title: Aid worker, Provider: Provider I, Score: 2.703908
# Job Title: Geophysicist/field seismologist, Provider: Provider S, Score: 2.703908
# Job Title: Pathologist, Provider: Provider B, Score: 2.703908
# Job Title: Technical author, Provider: Provider O, Score: 2.703908
# Job Title: Oceanographer, Provider: Provider D, Score: 2.703908
# Job Title: Surveyor, insurance, Provider: Provider A, Score: 2.703908
# Job Title: Landscape architect, Provider: Provider A, Score: 2.703908
# Job Title: Therapist, nutritional, Provider: Provider E, Score: 2.4673893
# Job Title: Press sub, Provider: Provider K, Score: 2.4673893
# Job Title: Conservator, furniture, Provider: Provider B, Score: 2.4673893
# Job Title: Intelligence analyst, Provider: Provider H, Score: 2.4673893
# Job Title: Theme park manager, Provider: Provider K, Score: 2.4673893
# Job Title: Fitness centre manager, Provider: Provider L, Score: 2.4673893
# Job Title: Probation officer, Provider: Provider X, Score: 2.4673893
# Job Title: Higher education lecturer, Provider: Provider Y, Score: 2.4673893
# Job Title: Environmental consultant, Provider: Provider B, Score: 2.4673893
# Job Title: Clinical scientist, histocompatibility and immunogenetics, Provider: Provider C, Score: 2.4673893
# Job Title: Location manager, Provider: Provider E, Score: 2.4673893
# Job Title: Architect, Provider: Provider E, Score: 2.4673893
# Job Title: Scientist, research (maths), Provider: Provider T, Score: 2.4673893
# Job Title: Librarian, public, Provider: Provider C, Score: 2.4673893
# Job Title: Biomedical scientist, Provider: Provider K, Score: 2.4673893
# Job Title: Designer, graphic, Provider: Provider P, Score: 2.4673893
# Job Title: Engineer, land, Provider: Provider B, Score: 2.4673893
# Job Title: Automotive engineer, Provider: Provider G, Score: 2.4673893
# Job Title: Designer, blown glass/stained glass, Provider: Provider H, Score: 2.4673893
# Job Title: Scientific laboratory technician, Provider: Provider Z, Score: 2.4673893
# Job Title: Clinical molecular geneticist, Provider: Provider K, Score: 2.4673893
# Job Title: Equities trader, Provider: Provider B, Score: 2.4673893
# Job Title: Careers adviser, Provider: Provider F, Score: 2.4673893
# Job Title: Banker, Provider: Provider R, Score: 2.4673893
# Job Title: Conservation officer, historic buildings, Provider: Provider H, Score: 2.4673893
# Job Title: Diplomatic Services operational officer, Provider: Provider I, Score: 2.4673893
# Job Title: Therapist, art, Provider: Provider K, Score: 2.4673893
# Job Title: Legal executive, Provider: Provider A, Score: 2.4673893
# Job Title: Comptroller, Provider: Provider G, Score: 2.4673893
# Job Title: Administrator, arts, Provider: Provider I, Score: 2.4673893
# Job Title: Clinical research associate, Provider: Provider Z, Score: 2.4673893
# Job Title: Psychologist, occupational, Provider: Provider Q, Score: 2.2689204
# Job Title: Engineer, land, Provider: Provider M, Score: 2.2689204
# Job Title: Therapist, horticultural, Provider: Provider U, Score: 2.2689204
# Job Title: Designer, ceramics/pottery, Provider: Provider L, Score: 2.2689204
# Job Title: Systems analyst, Provider: Provider V, Score: 2.2689204
# Job Title: General practice doctor, Provider: Provider D, Score: 2.2689204
# C:\Users\acer\AppData\Local\Temp\ipykernel_20176\1543085796.py:28: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.15/security-minimal-setup.html to enable security.
#   results = es.search(index="job_listings", body=query_body)
